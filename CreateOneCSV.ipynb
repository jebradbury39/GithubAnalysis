# %%
import pandas as pd
import os
import ast

# %%
def getAllFilenames(dirPath, exclude=[]):
    filenames = []
    for filename in os.listdir(dirPath):
        if filename not in exclude:
            filenames.append(filename)
    return filenames

# %%
filenames = getAllFilenames("/share/GithubAnalysis/pullFiles/", ["combined", "Pulls_VS_Total.csv"])

# %%
filenames
# Out:
# ['2016-12-12.csv',
#  '2016-12-03.csv',
#  '2016-12-04.csv',
#  '2016-12-17.csv',
#  '2016-12-24.csv',
#  '2016-12-06.csv',
#  '2016-12-01.csv',
#  '2016-12-19.csv',
#  '2016-12-26.csv',
#  '2016-12-21.csv',
#  '2016-12-20.csv',
#  '2016-12-15.csv',
#  '2016-12-23.csv',
#  '2016-12-29.csv',
#  '2016-12-10.csv',
#  '2016-12-05.csv',
#  '2016-12-16.csv',
#  '2016-12-27.csv',
#  '2016-12-14.csv',
#  '2016-12-31.csv',
#  '2016-12-11.csv',
#  '2016-12-30.csv',
#  '2016-12-28.csv',
#  '2016-12-25.csv',
#  '2016-12-18.csv',
#  '2016-12-22.csv',
#  '2016-12-02.csv',
#  '2016-12-09.csv',
#  '2016-12-07.csv',
#  '2016-12-08.csv',
#  '2016-12-13.csv']

# %% [markdown]
# doc = {
#         "user_login": [],
#         "forks_count": [],
#         "language": [],
#         "has_wiki": [],
#         "watchers": [],
#         "size": [],
#         "additions": [],
#         "created_at": [],
#         "default_branch": [],
#         "open_issues_count": [],
#         "name": [],
#         "description": [],
#         "size": []
#     }

# %%
def getValue(payload, path):
    root = payload
    for pathItem in path:
        if pathItem not in root:
            return None
        root = root[pathItem]
    return root
        
def pickRowData(df, doc):
    payload = ast.literal_eval(df["payload"])
    doc["event_time"].append(df["created_at"])
    doc["user_login"].append(getValue(payload, ["pull_request", "user", "login"]))
    doc["forks_count"].append(getValue(payload, ["pull_request", "base", "repo", "forks_count"]))
    doc["language"].append(getValue(payload, ["pull_request", "base", "repo", "language"]))
    doc["has_wiki"].append(getValue(payload, ["pull_request", "base", "repo", "has_wiki"]))
    doc["watchers_count"].append(getValue(payload, ["pull_request", "base", "repo", "watchers_count"]))
    doc["size"].append(getValue(payload, ["pull_request", "base", "repo", "size"]))
    doc["additions"].append(getValue(payload, ["pull_request", "additions"]))
    doc["deletions"].append(getValue(payload, ["pull_request", "deletions"]))
    doc["changed_files"].append(getValue(payload, ["pull_request", "changed_files"]))
    doc["number_commits"].append(getValue(payload, ["pull_request", "commits"]))
    doc["created_at"].append(getValue(payload, ["pull_request", "base", "repo", "created_at"]))
    doc["open_issues_count"].append(getValue(payload, ["pull_request", "base", "repo", "open_issues_count"]))
    doc["name"].append(getValue(payload, ["pull_request", "base", "repo", "name"]))
    doc["description"].append(getValue(payload, ["pull_request", "base", "repo", "description"]))
    doc["body"].append(getValue(payload, ["pull_request", "body"]))
    if df["type"] == "PullRequestReviewCommentEvent":
        doc["secondary_user"].append(getValue(payload, ["comment", "user", "login"]))
    else:
        doc["secondary_user"].append(None)
    
doc = {
    "event_time": [],
    "user_login": [],
    "secondary_user": [],
    "forks_count": [],
    "language": [],
    "has_wiki": [],
    "watchers_count": [],
    "size": [],
    "additions": [],
    "deletions": [],
    "changed_files": [],
    "number_commits": [],
    "created_at": [],
    "open_issues_count": [],
    "name": [],
    "description": [],
    "body": []
}
for filename in filenames:
    print(filename)
    data = pd.read_csv("/share/GithubAnalysis/pullFiles/" + filename)
    for index, row in data.iterrows():
        pickRowData(row, doc)
allData = pd.DataFrame(doc)
allData
# Out:
# 2016-12-12.csv

# %%
data = pd.read_csv("/share/GithubAnalysis/pullFiles/2016-12-12.csv")
data
# Out:
#        Unnamed: 0                                              actor  \
# 0           17381  {'url': 'https://api.github.com/users/Sonicthe...
# 1           11759  {'url': 'https://api.github.com/users/jdomenmi...
# 2            8198  {'url': 'https://api.github.com/users/ronsigal...
# 3            5430  {'url': 'https://api.github.com/users/storandr...
# 4           24035  {'url': 'https://api.github.com/users/jlog1994...
# 5            8063  {'url': 'https://api.github.com/users/ronsigal...
# 6           25438  {'url': 'https://api.github.com/users/yamamoto...
# 7             454  {'url': 'https://api.github.com/users/Bomret',...
# 8           31026  {'url': 'https://api.github.com/users/nima-vov...
# 9            8003  {'url': 'https://api.github.com/users/npranto'...
# 10          21888  {'url': 'https://api.github.com/users/kimkyung...
# 11          22681  {'url': 'https://api.github.com/users/Bohdankm...
# 12          28971  {'url': 'https://api.github.com/users/sovereig...
# 13           3242  {'url': 'https://api.github.com/users/greenkee...
# 14            879  {'url': 'https://api.github.com/users/sleaze',...
# 15          10627  {'url': 'https://api.github.com/users/workers-...
# 16          18365  {'url': 'https://api.github.com/users/houndci-...
# 17          28095  {'url': 'https://api.github.com/users/TSPcoder...
# 18           6878  {'url': 'https://api.github.com/users/allthebl...
# 19           1854  {'url': 'https://api.github.com/users/praveenk...
# 20          20730  {'url': 'https://api.github.com/users/varkor',...
# 21           4050  {'url': 'https://api.github.com/users/b264', '...
# 22          10594  {'url': 'https://api.github.com/users/goncalot...
# 23           8327  {'url': 'https://api.github.com/users/Jordan10...
# 24          15339  {'url': 'https://api.github.com/users/magul', ...
# 25           6169  {'url': 'https://api.github.com/users/dominic-...
# 26           3171  {'url': 'https://api.github.com/users/jhudzik'...
# 27           8405  {'url': 'https://api.github.com/users/platinum...
# 28          14132  {'url': 'https://api.github.com/users/greenkee...
# 29          14129  {'url': 'https://api.github.com/users/ThoseGra...
# ...           ...                                                ...
# 16098       28041  {'url': 'https://api.github.com/users/rosseji'...
# 16099       38125  {'url': 'https://api.github.com/users/pvogenth...
# 16100       40544  {'url': 'https://api.github.com/users/greenkee...
# 16101       39533  {'url': 'https://api.github.com/users/albertrd...
# 16102       38412  {'url': 'https://api.github.com/users/Jefftheb...
# 16103       42774  {'url': 'https://api.github.com/users/pyup-bot...
# 16104       33651  {'url': 'https://api.github.com/users/neozenit...
# 16105       32901  {'url': 'https://api.github.com/users/sjackman...
# 16106        7531  {'url': 'https://api.github.com/users/bharihar...
# 16107       16810  {'url': 'https://api.github.com/users/Trabalho...
# 16108       18143  {'url': 'https://api.github.com/users/wattmals...
# 16109       19816  {'url': 'https://api.github.com/users/eteq', '...
# 16110       25712  {'url': 'https://api.github.com/users/LevytsRo...
# 16111        5280  {'url': 'https://api.github.com/users/lmazuel'...
# 16112       11050  {'url': 'https://api.github.com/users/mystiber...
# 16113       40498  {'url': 'https://api.github.com/users/jensmaur...
# 16114       32540  {'url': 'https://api.github.com/users/JavaJimb...
# 16115       39596  {'url': 'https://api.github.com/users/greenkee...
# 16116       11690  {'url': 'https://api.github.com/users/paulomar...
# 16117       15919  {'url': 'https://api.github.com/users/sryza', ...
# 16118       23005  {'url': 'https://api.github.com/users/kyleknap...
# 16119       34549  {'url': 'https://api.github.com/users/thmslld'...
# 16120       37165  {'url': 'https://api.github.com/users/rohit2b'...
# 16121       13162  {'url': 'https://api.github.com/users/sauron-d...
# 16122       29803  {'url': 'https://api.github.com/users/YannickB...
# 16123       41837  {'url': 'https://api.github.com/users/samg', '...
# 16124        3812  {'url': 'https://api.github.com/users/DavidMor...
# 16125       14313  {'url': 'https://api.github.com/users/giulr', ...
# 16126       39534  {'url': 'https://api.github.com/users/justinal...
# 16127       23292  {'url': 'https://api.github.com/users/BillyDee...
#
#                 created_at          id  \
# 0      2016-12-12 00:32:15  5003684645
# 1      2016-12-12 00:21:50  5003665395
# 2      2016-12-12 00:15:40  5003654387
# 3      2016-12-12 00:10:56  5003645988
# 4      2016-12-12 00:45:07  5003707019
# 5      2016-12-12 00:15:28  5003654024
# 6      2016-12-12 00:47:50  5003711701
# 7      2016-12-12 00:00:45  5003628406
# 8      2016-12-12 00:58:29  5003731006
# 9      2016-12-12 00:15:24  5003653881
# 10     2016-12-12 00:41:10  5003699946
# 11     2016-12-12 00:42:34  5003702540
# 12     2016-12-12 00:54:36  5003724101
# 13     2016-12-12 00:06:19  5003638470
# 14     2016-12-12 00:01:38  5003630167
# 15     2016-12-12 00:19:59  5003661715
# 16     2016-12-12 00:34:09  5003687968
# 17     2016-12-12 00:52:57  5003721070
# 18     2016-12-12 00:13:28  5003650569
# 19     2016-12-12 00:03:42  5003633960
# 20     2016-12-12 00:38:52  5003695990
# 21     2016-12-12 00:07:54  5003641108
# 22     2016-12-12 00:19:55  5003661611
# 23     2016-12-12 00:15:52  5003654734
# 24     2016-12-12 00:28:30  5003677459
# 25     2016-12-12 00:12:12  5003648367
# 26     2016-12-12 00:06:11  5003638213
# 27     2016-12-12 00:16:00  5003654938
# 28     2016-12-12 00:26:06  5003673211
# 29     2016-12-12 00:26:05  5003673197
# ...                    ...         ...
# 16098  2016-12-12 23:37:12  5009840664
# 16099  2016-12-12 23:52:34  5009906638
# 16100  2016-12-12 23:56:08  5009922372
# 16101  2016-12-12 23:54:39  5009915837
# 16102  2016-12-12 23:53:02  5009908653
# 16103  2016-12-12 23:59:27  5009936396
# 16104  2016-12-12 23:45:36  5009877071
# 16105  2016-12-12 23:44:37  5009872810
# 16106  2016-12-12 23:09:23  5009707066
# 16107  2016-12-12 23:21:26  5009767938
# 16108  2016-12-12 23:23:12  5009776350
# 16109  2016-12-12 23:25:16  5009786346
# 16110  2016-12-12 23:33:46  5009825449
# 16111  2016-12-12 23:06:36  5009692020
# 16112  2016-12-12 23:14:10  5009731644
# 16113  2016-12-12 23:56:05  5009922132
# 16114  2016-12-12 23:44:08  5009870753
# 16115  2016-12-12 23:54:44  5009916273
# 16116  2016-12-12 23:15:03  5009736094
# 16117  2016-12-12 23:20:14  5009762056
# 16118  2016-12-12 23:29:36  5009806548
# 16119  2016-12-12 23:46:50  5009882273
# 16120  2016-12-12 23:51:03  5009899978
# 16121  2016-12-12 23:16:56  5009745434
# 16122  2016-12-12 23:39:58  5009852774
# 16123  2016-12-12 23:58:01  5009930505
# 16124  2016-12-12 23:04:38  5009682194
# 16125  2016-12-12 23:18:19  5009752251
# 16126  2016-12-12 23:54:39  5009915838
# 16127  2016-12-12 23:30:09  5009809057
#
#                                                      org  \
# 0      {'gravatar_id': '', 'login': 'adventurerscodex...
# 1                                                    NaN
# 2      {'gravatar_id': '', 'login': 'resteasy', 'avat...
# 3                                                    NaN
# 4                                                    NaN
# 5      {'gravatar_id': '', 'login': 'resteasy', 'avat...
# 6                                                    NaN
# 7                                                    NaN
# 8      {'gravatar_id': '', 'login': 'geekhub-php', 'a...
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13     {'gravatar_id': '', 'login': 'code-corps', 'av...
# 14                                                   NaN
# 15                                                   NaN
# 16     {'gravatar_id': '', 'login': 'dn-m', 'avatar_u...
# 17     {'gravatar_id': '', 'login': 'ProjetArchi-grou...
# 18                                                   NaN
# 19                                                   NaN
# 20     {'gravatar_id': '', 'login': 'hackcambridge', ...
# 21     {'gravatar_id': '', 'login': 'AgileVentures', ...
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25     {'gravatar_id': '', 'login': 'digital-profile'...
# 26                                                   NaN
# 27     {'gravatar_id': '', 'login': 'eslint', 'avatar...
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 16098  {'gravatar_id': '', 'login': 'youngstreetiniti...
# 16099  {'gravatar_id': '', 'login': 'majesticmushroom...
# 16100  {'gravatar_id': '', 'login': 'karma-runner', '...
# 16101  {'gravatar_id': '', 'login': 'lumoslabs', 'ava...
# 16102  {'gravatar_id': '', 'login': 'zulip', 'avatar_...
# 16103                                                NaN
# 16104                                                NaN
# 16105  {'gravatar_id': '', 'login': 'Linuxbrew', 'ava...
# 16106  {'gravatar_id': '', 'login': 'forcedotcom', 'a...
# 16107                                                NaN
# 16108  {'gravatar_id': '', 'login': 'tremendous-turni...
# 16109  {'gravatar_id': '', 'login': 'astropy', 'avata...
# 16110                                                NaN
# 16111  {'gravatar_id': '', 'login': 'Azure', 'avatar_...
# 16112  {'gravatar_id': '', 'login': 'okta', 'avatar_u...
# 16113  {'gravatar_id': '', 'login': 'cplusplus', 'ava...
# 16114                                                NaN
# 16115                                                NaN
# 16116  {'gravatar_id': '', 'login': 'Azure', 'avatar_...
# 16117  {'gravatar_id': '', 'login': 'airbnb', 'avatar...
# 16118  {'gravatar_id': '', 'login': 'boto', 'avatar_u...
# 16119                                                NaN
# 16120  {'gravatar_id': '', 'login': 'apollostack', 'a...
# 16121  {'gravatar_id': '', 'login': 'sauron-demo', 'a...
# 16122  {'gravatar_id': '', 'login': 'clouder-images',...
# 16123                                                NaN
# 16124  {'gravatar_id': '', 'login': 'MonetDB', 'avata...
# 16125                                                NaN
# 16126                                                NaN
# 16127  {'gravatar_id': '', 'login': 'codefellows-port...
#
#                                                  payload public  \
# 0      {'pull_request': {'additions': 81, 'url': 'htt...   True
# 1      {'pull_request': {'additions': 366, 'url': 'ht...   True
# 2      {'pull_request': {'additions': 104, 'url': 'ht...   True
# 3      {'pull_request': {'additions': 4380, 'url': 'h...   True
# 4      {'pull_request': {'additions': 1, 'url': 'http...   True
# 5      {'pull_request': {'additions': 213, 'url': 'ht...   True
# 6      {'pull_request': {'additions': 10, 'url': 'htt...   True
# 7      {'pull_request': {'additions': 1, 'url': 'http...   True
# 8      {'pull_request': {'additions': 10527, 'url': '...   True
# 9      {'pull_request': {'additions': 5, 'url': 'http...   True
# 10     {'pull_request': {'additions': 1, 'url': 'http...   True
# 11     {'pull_request': {'additions': 204, 'url': 'ht...   True
# 12     {'pull_request': {'additions': 0, 'url': 'http...   True
# 13     {'pull_request': {'additions': 1, 'url': 'http...   True
# 14     {'pull_request': {'additions': 7, 'url': 'http...   True
# 15     {'pull_request': {'additions': 51, 'url': 'htt...   True
# 16     {'pull_request': {'url': 'https://api.github.c...   True
# 17     {'pull_request': {'additions': 155, 'url': 'ht...   True
# 18     {'pull_request': {'additions': 1, 'url': 'http...   True
# 19     {'pull_request': {'additions': 1688, 'url': 'h...   True
# 20     {'pull_request': {'additions': 17, 'url': 'htt...   True
# 21     {'pull_request': {'additions': 53, 'url': 'htt...   True
# 22     {'pull_request': {'additions': 396, 'url': 'ht...   True
# 23     {'pull_request': {'additions': 0, 'url': 'http...   True
# 24     {'pull_request': {'additions': 23, 'url': 'htt...   True
# 25     {'pull_request': {'additions': 576, 'url': 'ht...   True
# 26     {'pull_request': {'additions': 22, 'url': 'htt...   True
# 27     {'pull_request': {'additions': 8, 'url': 'http...   True
# 28     {'pull_request': {'additions': 1, 'url': 'http...   True
# 29     {'pull_request': {'additions': 228, 'url': 'ht...   True
# ...                                                  ...    ...
# 16098  {'pull_request': {'additions': 687, 'url': 'ht...   True
# 16099  {'pull_request': {'additions': 4, 'url': 'http...   True
# 16100  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16101  {'pull_request': {'additions': 4, 'url': 'http...   True
# 16102  {'pull_request': {'additions': 3, 'url': 'http...   True
# 16103  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16104  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16105  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16106  {'pull_request': {'additions': 0, 'url': 'http...   True
# 16107  {'pull_request': {'additions': 79, 'url': 'htt...   True
# 16108  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16109  {'pull_request': {'additions': 308, 'url': 'ht...   True
# 16110  {'pull_request': {'additions': 240, 'url': 'ht...   True
# 16111  {'pull_request': {'additions': 415, 'url': 'ht...   True
# 16112  {'pull_request': {'additions': 56, 'url': 'htt...   True
# 16113  {'pull_request': {'additions': 182, 'url': 'ht...   True
# 16114  {'pull_request': {'additions': 56, 'url': 'htt...   True
# 16115  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16116  {'pull_request': {'additions': 35, 'url': 'htt...   True
# 16117  {'pull_request': {'additions': 4, 'url': 'http...   True
# 16118  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16119  {'pull_request': {'additions': 1449, 'url': 'h...   True
# 16120  {'pull_request': {'additions': 3, 'url': 'http...   True
# 16121  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16122  {'pull_request': {'additions': 1, 'url': 'http...   True
# 16123  {'pull_request': {'additions': 13, 'url': 'htt...   True
# 16124  {'pull_request': {'additions': 2, 'url': 'http...   True
# 16125  {'pull_request': {'additions': 190, 'url': 'ht...   True
# 16126  {'pull_request': {'additions': 171, 'url': 'ht...   True
# 16127  {'pull_request': {'additions': 37, 'url': 'htt...   True
#
#                                                     repo  \
# 0      {'name': 'adventurerscodex/adventurerscodex.gi...
# 1      {'name': 'NestorTejero/ES2016B', 'url': 'https...
# 2      {'name': 'resteasy/Resteasy', 'url': 'https://...
# 3      {'name': 'storandrew/Renju', 'url': 'https://a...
# 4      {'name': 'jlog1994/proyect', 'url': 'https://a...
# 5      {'name': 'resteasy/Resteasy', 'url': 'https://...
# 6      {'name': 'yamamoto-febc/sacloud-upload-image',...
# 7      {'name': 'Bomret/funkster-http-json', 'url': '...
# 8      {'name': 'geekhub-php/blog', 'url': 'https://a...
# 9      {'name': 'npranto/feeder', 'url': 'https://api...
# 10     {'name': 'sktkstka/obigoProject', 'url': 'http...
# 11     {'name': 'Bohdankm22/recipeBookASP', 'url': 'h...
# 12     {'name': 'sovereignmind/cs673f16-team1', 'url'...
# 13     {'name': 'code-corps/code-corps-ember', 'url':...
# 14     {'name': '4pr0n/ripme', 'url': 'https://api.gi...
# 15     {'name': 'workers-safety/workers-safety-websit...
# 16     {'name': 'dn-m/ArithmeticTools', 'url': 'https...
# 17     {'name': 'ProjetArchi-groupeDAT/Projet_Archite...
# 18     {'name': 'Makuna/NeoPixelBus', 'url': 'https:/...
# 19     {'name': 'praveenkumaresan/javamaterials', 'ur...
# 20     {'name': 'hackcambridge/hack-cambridge-website...
# 21     {'name': 'AgileVentures/osra', 'url': 'https:/...
# 22     {'name': 'goncalotomas/software-security', 'ur...
# 23     {'name': 'talandaw/newcodeconsultants', 'url':...
# 24     {'name': 'magul/pywikibot-core', 'url': 'https...
# 25     {'name': 'digital-profile/digital-profile.gith...
# 26     {'name': 'jhudzik/stroller-dessert', 'url': 'h...
# 27     {'name': 'eslint/eslint', 'url': 'https://api....
# 28     {'name': 'claireparker/precomm-spellcheck', 'u...
# 29     {'name': 'dackJavies/Text-Engine', 'url': 'htt...
# ...                                                  ...
# 16098  {'name': 'youngstreetinitiative/ysi', 'url': '...
# 16099  {'name': 'majesticmushrooms/majesticmushrooms'...
# 16100  {'name': 'karma-runner/karma-opera-launcher', ...
# 16101  {'name': 'lumoslabs/docker-chef', 'url': 'http...
# 16102  {'name': 'zulip/zulip-gci', 'url': 'https://ap...
# 16103  {'name': 'aaront/puckdb', 'url': 'https://api....
# 16104  {'name': 'neozenith/vim-dotfiles', 'url': 'htt...
# 16105  {'name': 'Linuxbrew/homebrew-core', 'url': 'ht...
# 16106  {'name': 'forcedotcom/SmartSyncExplorerReactNa...
# 16107  {'name': 'TrabalhoOO/SistemaTeatro', 'url': 'h...
# 16108  {'name': 'tremendous-turnips/tremendous-turnip...
# 16109  {'name': 'astropy/astropy', 'url': 'https://ap...
# 16110  {'name': 'LevytsRoman/levytsroman.github.io', ...
# 16111  {'name': 'Azure/azure-sdk-for-python', 'url': ...
# 16112  {'name': 'okta/okta.github.io', 'url': 'https:...
# 16113  {'name': 'cplusplus/draft', 'url': 'https://ap...
# 16114  {'name': 'JavaJimbo/Manchester-18F', 'url': 'h...
# 16115  {'name': 'AvraamMavridis/react-autocomplete-co...
# 16116  {'name': 'Azure/azure-quickstart-templates', '...
# 16117  {'name': 'airbnb/knowledge-repo', 'url': 'http...
# 16118  {'name': 'boto/s3transfer', 'url': 'https://ap...
# 16119  {'name': 'thmslld/bloggero-elm-mdl', 'url': 'h...
# 16120  {'name': 'apollostack/optics-agent-js', 'url':...
# 16121  {'name': 'sauron-demo/sauron-demo', 'url': 'ht...
# 16122  {'name': 'clouder-images/clouder-odoo9-clouder...
# 16123  {'name': 'samg/timetrap', 'url': 'https://api....
# 16124  {'name': 'MonetDB/monetdb-r-docker', 'url': 'h...
# 16125  {'name': 'giulr/redes', 'url': 'https://api.gi...
# 16126  {'name': 'justinal64/TheBibleApp', 'url': 'htt...
# 16127  {'name': 'codefellows-portland-301d7/01-mobile...
#
#                                 type
# 0                   PullRequestEvent
# 1                   PullRequestEvent
# 2                   PullRequestEvent
# 3                   PullRequestEvent
# 4                   PullRequestEvent
# 5                   PullRequestEvent
# 6                   PullRequestEvent
# 7                   PullRequestEvent
# 8                   PullRequestEvent
# 9                   PullRequestEvent
# 10                  PullRequestEvent
# 11                  PullRequestEvent
# 12                  PullRequestEvent
# 13                  PullRequestEvent
# 14                  PullRequestEvent
# 15                  PullRequestEvent
# 16     PullRequestReviewCommentEvent
# 17                  PullRequestEvent
# 18                  PullRequestEvent
# 19                  PullRequestEvent
# 20                  PullRequestEvent
# 21                  PullRequestEvent
# 22                  PullRequestEvent
# 23                  PullRequestEvent
# 24                  PullRequestEvent
# 25                  PullRequestEvent
# 26                  PullRequestEvent
# 27                  PullRequestEvent
# 28                  PullRequestEvent
# 29                  PullRequestEvent
# ...                              ...
# 16098               PullRequestEvent
# 16099               PullRequestEvent
# 16100               PullRequestEvent
# 16101               PullRequestEvent
# 16102               PullRequestEvent
# 16103               PullRequestEvent
# 16104               PullRequestEvent
# 16105               PullRequestEvent
# 16106               PullRequestEvent
# 16107               PullRequestEvent
# 16108               PullRequestEvent
# 16109               PullRequestEvent
# 16110               PullRequestEvent
# 16111               PullRequestEvent
# 16112               PullRequestEvent
# 16113               PullRequestEvent
# 16114               PullRequestEvent
# 16115               PullRequestEvent
# 16116               PullRequestEvent
# 16117               PullRequestEvent
# 16118               PullRequestEvent
# 16119               PullRequestEvent
# 16120               PullRequestEvent
# 16121               PullRequestEvent
# 16122               PullRequestEvent
# 16123               PullRequestEvent
# 16124               PullRequestEvent
# 16125               PullRequestEvent
# 16126               PullRequestEvent
# 16127               PullRequestEvent
#
# [16128 rows x 9 columns]

# %%
ast.literal_eval(data["payload"].iloc[27])
# Out:
# {'action': 'opened',
#  'number': 7743,
#  'pull_request': {'_links': {'comments': {'href': 'https://api.github.com/repos/eslint/eslint/issues/7743/comments'},
#    'commits': {'href': 'https://api.github.com/repos/eslint/eslint/pulls/7743/commits'},
#    'html': {'href': 'https://github.com/eslint/eslint/pull/7743'},
#    'issue': {'href': 'https://api.github.com/repos/eslint/eslint/issues/7743'},
#    'review_comment': {'href': 'https://api.github.com/repos/eslint/eslint/pulls/comments{/number}'},
#    'review_comments': {'href': 'https://api.github.com/repos/eslint/eslint/pulls/7743/comments'},
#    'self': {'href': 'https://api.github.com/repos/eslint/eslint/pulls/7743'},
#    'statuses': {'href': 'https://api.github.com/repos/eslint/eslint/statuses/0525d1c3506d7650274f4cd50c1250bc784965a0'}},
#   'additions': 8,
#   'assignee': None,
#   'assignees': [],
#   'base': {'label': 'eslint:master',
#    'ref': 'master',
#    'repo': {'archive_url': 'https://api.github.com/repos/eslint/eslint/{archive_format}{/ref}',
#     'assignees_url': 'https://api.github.com/repos/eslint/eslint/assignees{/user}',
#     'blobs_url': 'https://api.github.com/repos/eslint/eslint/git/blobs{/sha}',
#     'branches_url': 'https://api.github.com/repos/eslint/eslint/branches{/branch}',
#     'clone_url': 'https://github.com/eslint/eslint.git',
#     'collaborators_url': 'https://api.github.com/repos/eslint/eslint/collaborators{/collaborator}',
#     'comments_url': 'https://api.github.com/repos/eslint/eslint/comments{/number}',
#     'commits_url': 'https://api.github.com/repos/eslint/eslint/commits{/sha}',
#     'compare_url': 'https://api.github.com/repos/eslint/eslint/compare/{base}...{head}',
#     'contents_url': 'https://api.github.com/repos/eslint/eslint/contents/{+path}',
#     'contributors_url': 'https://api.github.com/repos/eslint/eslint/contributors',
#     'created_at': '2013-06-29T23:59:48Z',
#     'default_branch': 'master',
#     'deployments_url': 'https://api.github.com/repos/eslint/eslint/deployments',
#     'description': 'A fully pluggable tool for identifying and reporting on patterns in JavaScript.',
#     'downloads_url': 'https://api.github.com/repos/eslint/eslint/downloads',
#     'events_url': 'https://api.github.com/repos/eslint/eslint/events',
#     'fork': False,
#     'forks': 1242,
#     'forks_count': 1242,
#     'forks_url': 'https://api.github.com/repos/eslint/eslint/forks',
#     'full_name': 'eslint/eslint',
#     'git_commits_url': 'https://api.github.com/repos/eslint/eslint/git/commits{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/eslint/eslint/git/refs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/eslint/eslint/git/tags{/sha}',
#     'git_url': 'git://github.com/eslint/eslint.git',
#     'has_downloads': True,
#     'has_issues': True,
#     'has_pages': False,
#     'has_wiki': False,
#     'homepage': 'http://eslint.org',
#     'hooks_url': 'https://api.github.com/repos/eslint/eslint/hooks',
#     'html_url': 'https://github.com/eslint/eslint',
#     'id': 11061773,
#     'issue_comment_url': 'https://api.github.com/repos/eslint/eslint/issues/comments{/number}',
#     'issue_events_url': 'https://api.github.com/repos/eslint/eslint/issues/events{/number}',
#     'issues_url': 'https://api.github.com/repos/eslint/eslint/issues{/number}',
#     'keys_url': 'https://api.github.com/repos/eslint/eslint/keys{/key_id}',
#     'labels_url': 'https://api.github.com/repos/eslint/eslint/labels{/name}',
#     'language': 'JavaScript',
#     'languages_url': 'https://api.github.com/repos/eslint/eslint/languages',
#     'merges_url': 'https://api.github.com/repos/eslint/eslint/merges',
#     'milestones_url': 'https://api.github.com/repos/eslint/eslint/milestones{/number}',
#     'mirror_url': None,
#     'name': 'eslint',
#     'notifications_url': 'https://api.github.com/repos/eslint/eslint/notifications{?since,all,participating}',
#     'open_issues': 290,
#     'open_issues_count': 290,
#     'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/6019716?v=3',
#      'events_url': 'https://api.github.com/users/eslint/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/eslint/followers',
#      'following_url': 'https://api.github.com/users/eslint/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eslint/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/eslint',
#      'id': 6019716,
#      'login': 'eslint',
#      'organizations_url': 'https://api.github.com/users/eslint/orgs',
#      'received_events_url': 'https://api.github.com/users/eslint/received_events',
#      'repos_url': 'https://api.github.com/users/eslint/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/eslint/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eslint/subscriptions',
#      'type': 'Organization',
#      'url': 'https://api.github.com/users/eslint'},
#     'private': False,
#     'pulls_url': 'https://api.github.com/repos/eslint/eslint/pulls{/number}',
#     'pushed_at': '2016-12-12T00:15:59Z',
#     'releases_url': 'https://api.github.com/repos/eslint/eslint/releases{/id}',
#     'size': 20758,
#     'ssh_url': 'git@github.com:eslint/eslint.git',
#     'stargazers_count': 6464,
#     'stargazers_url': 'https://api.github.com/repos/eslint/eslint/stargazers',
#     'statuses_url': 'https://api.github.com/repos/eslint/eslint/statuses/{sha}',
#     'subscribers_url': 'https://api.github.com/repos/eslint/eslint/subscribers',
#     'subscription_url': 'https://api.github.com/repos/eslint/eslint/subscription',
#     'svn_url': 'https://github.com/eslint/eslint',
#     'tags_url': 'https://api.github.com/repos/eslint/eslint/tags',
#     'teams_url': 'https://api.github.com/repos/eslint/eslint/teams',
#     'trees_url': 'https://api.github.com/repos/eslint/eslint/git/trees{/sha}',
#     'updated_at': '2016-12-11T22:21:47Z',
#     'url': 'https://api.github.com/repos/eslint/eslint',
#     'watchers': 6464,
#     'watchers_count': 6464},
#    'sha': 'df2f1158594ad9d6c019715fd050f8da1f06fe67',
#    'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/6019716?v=3',
#     'events_url': 'https://api.github.com/users/eslint/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/eslint/followers',
#     'following_url': 'https://api.github.com/users/eslint/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/eslint/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/eslint',
#     'id': 6019716,
#     'login': 'eslint',
#     'organizations_url': 'https://api.github.com/users/eslint/orgs',
#     'received_events_url': 'https://api.github.com/users/eslint/received_events',
#     'repos_url': 'https://api.github.com/users/eslint/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/eslint/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/eslint/subscriptions',
#     'type': 'Organization',
#     'url': 'https://api.github.com/users/eslint'}},
#   'body': '**What is the purpose of this pull request? (put an "X" next to item)**\r\n\r\n[x] Documentation update\r\n\r\n<!--\r\n    The following is required for all pull requests:\r\n-->\r\n\r\n**What changes did you make? (Give an overview)**\r\n\r\nEnsured that `no-restricted-globals`, `no-restricted-properties`, and `no-restricted-syntax` all linked to each other in their documentation.\r\n\r\n**Is there anything you\'d like reviewers to focus on?**\r\n\r\nI\'m not sure `no-restricted-syntax` really fits with `no-restricted-globals` and `no-restricted-properties`, but there was already a link between `no-restricted-properties` and `no-restricted-syntax`. Should I instead remove `no-restricted-syntax` from the other two rules? `no-restricted-syntax` points to rules like `no-debugger` which it supersedes.',
#   'changed_files': 3,
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/eslint/eslint/issues/7743/comments',
#   'commits': 1,
#   'commits_url': 'https://api.github.com/repos/eslint/eslint/pulls/7743/commits',
#   'created_at': '2016-12-12T00:15:59Z',
#   'deletions': 0,
#   'diff_url': 'https://github.com/eslint/eslint/pull/7743.diff',
#   'head': {'label': 'eslint:no-restricted-docs',
#    'ref': 'no-restricted-docs',
#    'repo': {'archive_url': 'https://api.github.com/repos/eslint/eslint/{archive_format}{/ref}',
#     'assignees_url': 'https://api.github.com/repos/eslint/eslint/assignees{/user}',
#     'blobs_url': 'https://api.github.com/repos/eslint/eslint/git/blobs{/sha}',
#     'branches_url': 'https://api.github.com/repos/eslint/eslint/branches{/branch}',
#     'clone_url': 'https://github.com/eslint/eslint.git',
#     'collaborators_url': 'https://api.github.com/repos/eslint/eslint/collaborators{/collaborator}',
#     'comments_url': 'https://api.github.com/repos/eslint/eslint/comments{/number}',
#     'commits_url': 'https://api.github.com/repos/eslint/eslint/commits{/sha}',
#     'compare_url': 'https://api.github.com/repos/eslint/eslint/compare/{base}...{head}',
#     'contents_url': 'https://api.github.com/repos/eslint/eslint/contents/{+path}',
#     'contributors_url': 'https://api.github.com/repos/eslint/eslint/contributors',
#     'created_at': '2013-06-29T23:59:48Z',
#     'default_branch': 'master',
#     'deployments_url': 'https://api.github.com/repos/eslint/eslint/deployments',
#     'description': 'A fully pluggable tool for identifying and reporting on patterns in JavaScript.',
#     'downloads_url': 'https://api.github.com/repos/eslint/eslint/downloads',
#     'events_url': 'https://api.github.com/repos/eslint/eslint/events',
#     'fork': False,
#     'forks': 1242,
#     'forks_count': 1242,
#     'forks_url': 'https://api.github.com/repos/eslint/eslint/forks',
#     'full_name': 'eslint/eslint',
#     'git_commits_url': 'https://api.github.com/repos/eslint/eslint/git/commits{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/eslint/eslint/git/refs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/eslint/eslint/git/tags{/sha}',
#     'git_url': 'git://github.com/eslint/eslint.git',
#     'has_downloads': True,
#     'has_issues': True,
#     'has_pages': False,
#     'has_wiki': False,
#     'homepage': 'http://eslint.org',
#     'hooks_url': 'https://api.github.com/repos/eslint/eslint/hooks',
#     'html_url': 'https://github.com/eslint/eslint',
#     'id': 11061773,
#     'issue_comment_url': 'https://api.github.com/repos/eslint/eslint/issues/comments{/number}',
#     'issue_events_url': 'https://api.github.com/repos/eslint/eslint/issues/events{/number}',
#     'issues_url': 'https://api.github.com/repos/eslint/eslint/issues{/number}',
#     'keys_url': 'https://api.github.com/repos/eslint/eslint/keys{/key_id}',
#     'labels_url': 'https://api.github.com/repos/eslint/eslint/labels{/name}',
#     'language': 'JavaScript',
#     'languages_url': 'https://api.github.com/repos/eslint/eslint/languages',
#     'merges_url': 'https://api.github.com/repos/eslint/eslint/merges',
#     'milestones_url': 'https://api.github.com/repos/eslint/eslint/milestones{/number}',
#     'mirror_url': None,
#     'name': 'eslint',
#     'notifications_url': 'https://api.github.com/repos/eslint/eslint/notifications{?since,all,participating}',
#     'open_issues': 290,
#     'open_issues_count': 290,
#     'owner': {'avatar_url': 'https://avatars.githubusercontent.com/u/6019716?v=3',
#      'events_url': 'https://api.github.com/users/eslint/events{/privacy}',
#      'followers_url': 'https://api.github.com/users/eslint/followers',
#      'following_url': 'https://api.github.com/users/eslint/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/eslint/gists{/gist_id}',
#      'gravatar_id': '',
#      'html_url': 'https://github.com/eslint',
#      'id': 6019716,
#      'login': 'eslint',
#      'organizations_url': 'https://api.github.com/users/eslint/orgs',
#      'received_events_url': 'https://api.github.com/users/eslint/received_events',
#      'repos_url': 'https://api.github.com/users/eslint/repos',
#      'site_admin': False,
#      'starred_url': 'https://api.github.com/users/eslint/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/eslint/subscriptions',
#      'type': 'Organization',
#      'url': 'https://api.github.com/users/eslint'},
#     'private': False,
#     'pulls_url': 'https://api.github.com/repos/eslint/eslint/pulls{/number}',
#     'pushed_at': '2016-12-12T00:15:59Z',
#     'releases_url': 'https://api.github.com/repos/eslint/eslint/releases{/id}',
#     'size': 20758,
#     'ssh_url': 'git@github.com:eslint/eslint.git',
#     'stargazers_count': 6464,
#     'stargazers_url': 'https://api.github.com/repos/eslint/eslint/stargazers',
#     'statuses_url': 'https://api.github.com/repos/eslint/eslint/statuses/{sha}',
#     'subscribers_url': 'https://api.github.com/repos/eslint/eslint/subscribers',
#     'subscription_url': 'https://api.github.com/repos/eslint/eslint/subscription',
#     'svn_url': 'https://github.com/eslint/eslint',
#     'tags_url': 'https://api.github.com/repos/eslint/eslint/tags',
#     'teams_url': 'https://api.github.com/repos/eslint/eslint/teams',
#     'trees_url': 'https://api.github.com/repos/eslint/eslint/git/trees{/sha}',
#     'updated_at': '2016-12-11T22:21:47Z',
#     'url': 'https://api.github.com/repos/eslint/eslint',
#     'watchers': 6464,
#     'watchers_count': 6464},
#    'sha': '0525d1c3506d7650274f4cd50c1250bc784965a0',
#    'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/6019716?v=3',
#     'events_url': 'https://api.github.com/users/eslint/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/eslint/followers',
#     'following_url': 'https://api.github.com/users/eslint/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/eslint/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/eslint',
#     'id': 6019716,
#     'login': 'eslint',
#     'organizations_url': 'https://api.github.com/users/eslint/orgs',
#     'received_events_url': 'https://api.github.com/users/eslint/received_events',
#     'repos_url': 'https://api.github.com/users/eslint/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/eslint/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/eslint/subscriptions',
#     'type': 'Organization',
#     'url': 'https://api.github.com/users/eslint'}},
#   'html_url': 'https://github.com/eslint/eslint/pull/7743',
#   'id': 97479982,
#   'issue_url': 'https://api.github.com/repos/eslint/eslint/issues/7743',
#   'locked': False,
#   'merge_commit_sha': '38aa3aaa6a354c28b88dfa8f910eb64de15073bd',
#   'mergeable': True,
#   'mergeable_state': 'unstable',
#   'merged': False,
#   'merged_at': None,
#   'merged_by': None,
#   'milestone': None,
#   'number': 7743,
#   'patch_url': 'https://github.com/eslint/eslint/pull/7743.patch',
#   'review_comment_url': 'https://api.github.com/repos/eslint/eslint/pulls/comments{/number}',
#   'review_comments': 0,
#   'review_comments_url': 'https://api.github.com/repos/eslint/eslint/pulls/7743/comments',
#   'state': 'open',
#   'statuses_url': 'https://api.github.com/repos/eslint/eslint/statuses/0525d1c3506d7650274f4cd50c1250bc784965a0',
#   'title': 'Docs: Rules restricting globals/properties/syntax are linked together',
#   'updated_at': '2016-12-12T00:15:59Z',
#   'url': 'https://api.github.com/repos/eslint/eslint/pulls/7743',
#   'user': {'avatar_url': 'https://avatars.githubusercontent.com/u/284282?v=3',
#    'events_url': 'https://api.github.com/users/platinumazure/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/platinumazure/followers',
#    'following_url': 'https://api.github.com/users/platinumazure/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/platinumazure/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/platinumazure',
#    'id': 284282,
#    'login': 'platinumazure',
#    'organizations_url': 'https://api.github.com/users/platinumazure/orgs',
#    'received_events_url': 'https://api.github.com/users/platinumazure/received_events',
#    'repos_url': 'https://api.github.com/users/platinumazure/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/platinumazure/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/platinumazure/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/platinumazure'}}}
