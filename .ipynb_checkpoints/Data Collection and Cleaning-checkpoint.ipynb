# %% [markdown]
# The number of programmers and how much they programmed on github.
# The most popular languages (does it change considering the holidays?).
#
# We make one api call for user
# {
#   "login": "caesar2164",
#   "name": "Giulio Gratta",
#   "company": null,
#   "location": "Stanford, CA",
#   "hireable": null,
#   "created_at": "2013-01-24T05:17:16Z",
# }
#
# One api call for repo
# {
#     "language", (primary lang only)
#     ...(ask professor (size, forks, format of api call))
#     "size" (in KB)
# }
#
# Two calls per row (auth api calls needed, w/5000 per hour)

# %%
import pandas as pd
import requests

import sys
sys.path.append("/home/jebradbury39/.local/lib/python3.5/site-packages")
from geopy.geocoders import Nominatim

# %%
auth = pd.read_csv("github.auth")

# %%
data = pd.read_json("/share/GithubAnalysis/2016-12-27-5.json", lines=True)
data
# Out:
#                                                    actor          created_at  \
# 0      {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 1      {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 2      {'display_login': 'pheigylim', 'login': 'pheig... 2016-12-27 05:00:00
# 3      {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 4      {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 5      {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 6      {'display_login': 'ndcRobot', 'login': 'ndcRob... 2016-12-27 05:00:00
# 7      {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 8      {'display_login': 'jasnell', 'login': 'jasnell... 2016-12-27 05:00:00
# 9      {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 10     {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 11     {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 12     {'display_login': 'hachinobu', 'login': 'hachi... 2016-12-27 05:00:00
# 13     {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 14     {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 15     {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 16     {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 17     {'display_login': 'fuzz6001', 'login': 'fuzz60... 2016-12-27 05:00:00
# 18     {'display_login': 'alex1582-kodigit', 'login':... 2016-12-27 05:00:00
# 19     {'display_login': 'zhangliting', 'login': 'zha... 2016-12-27 05:00:02
# 20     {'display_login': 'previoususername', 'login':... 2016-12-27 05:00:02
# 21     {'display_login': 'MayurDev', 'login': 'MayurD... 2016-12-27 05:00:02
# 22     {'display_login': 'zubinxiong', 'login': 'zubi... 2016-12-27 05:00:02
# 23     {'display_login': 'iambigd', 'login': 'iambigd... 2016-12-27 05:00:02
# 24     {'display_login': 'fagundes', 'login': 'fagund... 2016-12-27 05:00:02
# 25     {'display_login': 'amraboelela', 'login': 'amr... 2016-12-27 05:00:03
# 26     {'display_login': 'RenantDev', 'login': 'Renan... 2016-12-27 05:00:03
# 27     {'display_login': 'riseshia', 'login': 'risesh... 2016-12-27 05:00:03
# 28     {'display_login': 'hesiyi', 'login': 'hesiyi',... 2016-12-27 05:00:03
# 29     {'display_login': 'alex1582-ccloud', 'login': ... 2016-12-27 05:00:03
# ...                                                  ...                 ...
# 25591  {'display_login': 'saiedhp', 'login': 'saiedhp... 2016-12-27 05:59:56
# 25592  {'display_login': 'vivekjha2', 'login': 'vivek... 2016-12-27 05:59:56
# 25593  {'display_login': 'jeanpaulsio', 'login': 'jea... 2016-12-27 05:59:57
# 25594  {'display_login': 'alex1582-kodicc', 'login': ... 2016-12-27 05:59:57
# 25595  {'display_login': 'leranf', 'login': 'leranf',... 2016-12-27 05:59:57
# 25596  {'display_login': 'musicAbin', 'login': 'music... 2016-12-27 05:59:57
# 25597  {'display_login': 'BorisBochkaryov', 'login': ... 2016-12-27 05:59:57
# 25598  {'display_login': 'Andersbakken', 'login': 'An... 2016-12-27 05:59:58
# 25599  {'display_login': 'popomore', 'login': 'popomo... 2016-12-27 05:59:58
# 25600  {'display_login': 'xingganfengxing', 'login': ... 2016-12-27 05:59:58
# 25601  {'display_login': 'jimmyjam1', 'login': 'jimmy... 2016-12-27 05:59:58
# 25602  {'display_login': 'Lin-YingYu', 'login': 'Lin-... 2016-12-27 05:59:58
# 25603  {'display_login': 'zhangliuping', 'login': 'zh... 2016-12-27 05:59:58
# 25604  {'display_login': 'qel', 'login': 'qel', 'avat... 2016-12-27 05:59:58
# 25605  {'display_login': 'umairmunir-95', 'login': 'u... 2016-12-27 05:59:58
# 25606  {'display_login': 'umairmunir-95', 'login': 'u... 2016-12-27 05:59:58
# 25607  {'display_login': 'harman-DarrenChen', 'login'... 2016-12-27 05:59:58
# 25608  {'display_login': 'ipad4', 'login': 'ipad4', '... 2016-12-27 05:59:58
# 25609  {'display_login': 'KawayAlpaka', 'login': 'Kaw... 2016-12-27 05:59:59
# 25610  {'display_login': 'MacoTasu', 'login': 'MacoTa... 2016-12-27 05:59:59
# 25611  {'display_login': 'dieunb', 'login': 'dieunb',... 2016-12-27 05:55:11
# 25612  {'display_login': 'dieunb', 'login': 'dieunb',... 2016-12-27 05:57:09
# 25613  {'display_login': 'dieunb', 'login': 'dieunb',... 2016-12-27 05:57:50
# 25614  {'display_login': 'dieunb', 'login': 'dieunb',... 2016-12-27 05:58:37
# 25615  {'display_login': 'dieunb', 'login': 'dieunb',... 2016-12-27 05:58:45
# 25616  {'display_login': 'dieunb', 'login': 'dieunb',... 2016-12-27 05:59:40
# 25617  {'display_login': 'damithc', 'login': 'damithc... 2016-12-27 05:54:08
# 25618  {'display_login': 'damithc', 'login': 'damithc... 2016-12-27 05:55:22
# 25619  {'display_login': 'damithc', 'login': 'damithc... 2016-12-27 05:56:41
# 25620  {'display_login': 'tchaikov', 'login': 'tchaik... 2016-12-27 05:51:26
#
#                id                                                org  \
# 0      5072948680                                                NaN
# 1      5072948681                                                NaN
# 2      5072948683                                                NaN
# 3      5072948685                                                NaN
# 4      5072948686                                                NaN
# 5      5072948687                                                NaN
# 6      5072948688                                                NaN
# 7      5072948692                                                NaN
# 8      5072948694                                                NaN
# 9      5072948697                                                NaN
# 10     5072948699                                                NaN
# 11     5072948700                                                NaN
# 12     5072948703                                                NaN
# 13     5072948704                                                NaN
# 14     5072948705                                                NaN
# 15     5072948706                                                NaN
# 16     5072948710                                                NaN
# 17     5072948713                                                NaN
# 18     5072948715                                                NaN
# 19     5072948736  {'id': 12936068, 'avatar_url': 'https://avatar...
# 20     5072948738                                                NaN
# 21     5072948739                                                NaN
# 22     5072948763                                                NaN
# 23     5072948767  {'id': 1342004, 'avatar_url': 'https://avatars...
# 24     5072948771                                                NaN
# 25     5072948780                                                NaN
# 26     5072948783                                                NaN
# 27     5072948784                                                NaN
# 28     5072948785                                                NaN
# 29     5072948793                                                NaN
# ...           ...                                                ...
# 25591  5073053582                                                NaN
# 25592  5073053586                                                NaN
# 25593  5073053614                                                NaN
# 25594  5073053616                                                NaN
# 25595  5073053622                                                NaN
# 25596  5073053627                                                NaN
# 25597  5073053636                                                NaN
# 25598  5073053644                                                NaN
# 25599  5073053646  {'id': 15833670, 'avatar_url': 'https://avatar...
# 25600  5073053647                                                NaN
# 25601  5073053649                                                NaN
# 25602  5073053653                                                NaN
# 25603  5073053658  {'id': 82592, 'avatar_url': 'https://avatars.g...
# 25604  5073053659                                                NaN
# 25605  5073053667                                                NaN
# 25606  5073053669                                                NaN
# 25607  5073053671                                                NaN
# 25608  5073053673                                                NaN
# 25609  5073053678                                                NaN
# 25610  5073053679                                                NaN
# 25611  5073059210  {'id': 2322183, 'avatar_url': 'https://avatars...
# 25612  5073059211  {'id': 2322183, 'avatar_url': 'https://avatars...
# 25613  5073059213  {'id': 2322183, 'avatar_url': 'https://avatars...
# 25614  5073059214  {'id': 2322183, 'avatar_url': 'https://avatars...
# 25615  5073059215  {'id': 2322183, 'avatar_url': 'https://avatars...
# 25616  5073059216  {'id': 2322183, 'avatar_url': 'https://avatars...
# 25617  5073060377  {'id': 20763652, 'avatar_url': 'https://avatar...
# 25618  5073060378  {'id': 20763652, 'avatar_url': 'https://avatar...
# 25619  5073060379  {'id': 20763652, 'avatar_url': 'https://avatar...
# 25620  5073060893  {'id': 1015767, 'avatar_url': 'https://avatars...
#
#                                                  payload public  \
# 0      {'ref': 'nougat-mr1-release', 'ref_type': 'bra...   True
# 1      {'ref': 'nougat-release', 'ref_type': 'branch'...   True
# 2      {'ref': 'master', 'ref_type': 'branch', 'maste...   True
# 3      {'ref': 'lollipop-wear-release', 'ref_type': '...   True
# 4      {'ref': 'marshmallow-cts-release', 'ref_type':...   True
# 5      {'ref': 'marshmallow-dev', 'ref_type': 'branch...   True
# 6      {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 7      {'ref': 'marshmallow-dr-dev', 'ref_type': 'bra...   True
# 8      {'ref': 'url-updates', 'ref_type': 'branch', '...   True
# 9      {'ref': 'marshmallow-dr-dragon-release', 'ref_...   True
# 10     {'ref': 'marshmallow-dr-release', 'ref_type': ...   True
# 11     {'ref': 'marshmallow-mr1-dev', 'ref_type': 'br...   True
# 12     {'pull_request': {'milestone': None, 'html_url...   True
# 13     {'ref': 'marshmallow-mr1-release', 'ref_type':...   True
# 14     {'ref': 'marshmallow-mr2-release', 'ref_type':...   True
# 15     {'ref': 'marshmallow-mr3-release', 'ref_type':...   True
# 16     {'ref': 'marshmallow-release', 'ref_type': 'br...   True
# 17     {'ref': 'idea133-weekly-release', 'ref_type': ...   True
# 18     {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 19                                 {'action': 'started'}   True
# 20     {'forkee': {'public': True, 'assignees_url': '...   True
# 21                                 {'action': 'started'}   True
# 22                                 {'action': 'started'}   True
# 23                                 {'action': 'started'}   True
# 24     {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 25     {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 26     {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 27     {'pull_request': {'milestone': None, 'html_url...   True
# 28     {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 29     {'ref': 'refs/heads/master', 'push_id': 147382...   True
# ...                                                  ...    ...
# 25591  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 25592  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 25593  {'ref': 'refs/heads/polymorphic-comments', 'pu...   True
# 25594  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 25595  {'ref': 'master', 'ref_type': 'branch', 'maste...   True
# 25596                              {'action': 'started'}   True
# 25597                              {'action': 'started'}   True
# 25598  {'ref': 'refs/heads/gh-pages', 'push_id': 1473...   True
# 25599  {'comment': {'updated_at': '2016-12-27T05:59:5...   True
# 25600  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 25601  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 25602                              {'action': 'started'}   True
# 25603                              {'action': 'started'}   True
# 25604  {'ref': 'refs/heads/gh-pages', 'push_id': 1473...   True
# 25605  {'comment': {'updated_at': '2016-12-27T05:59:5...   True
# 25606  {'action': 'closed', 'issue': {'assignees': [{...   True
# 25607                              {'action': 'started'}   True
# 25608                              {'action': 'started'}   True
# 25609  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 25610  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 25611  {'pull_request': {'milestone': None, 'html_url...   True
# 25612  {'pull_request': {'milestone': None, 'html_url...   True
# 25613  {'pull_request': {'milestone': None, 'html_url...   True
# 25614  {'pull_request': {'milestone': None, 'html_url...   True
# 25615  {'pull_request': {'milestone': None, 'html_url...   True
# 25616  {'pull_request': {'milestone': None, 'html_url...   True
# 25617  {'pull_request': {'milestone': None, 'html_url...   True
# 25618  {'pull_request': {'milestone': None, 'html_url...   True
# 25619  {'pull_request': {'milestone': None, 'html_url...   True
# 25620  {'pull_request': {'milestone': None, 'html_url...   True
#
#                                                     repo  \
# 0      {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 1      {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 2      {'id': 77426931, 'name': 'pheigylim/hello-worl...
# 3      {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 4      {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 5      {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 6      {'id': 49482578, 'name': 'ndcRobot/cronMyself'...
# 7      {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 8      {'id': 37868459, 'name': 'jasnell/node', 'url'...
# 9      {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 10     {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 11     {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 12     {'id': 74805876, 'name': 'hachinobu/SamuraiTra...
# 13     {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 14     {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 15     {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 16     {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 17     {'id': 77426906, 'name': 'fuzz6001/volley', 'u...
# 18     {'id': 77416062, 'name': 'alex1582-kodigit/Mag...
# 19     {'id': 37991989, 'name': 'coodict/javascript-i...
# 20     {'id': 14158237, 'name': 'copy/v86', 'url': 'h...
# 21     {'id': 77010989, 'name': 'gjiazhe/PanoramaImag...
# 22     {'id': 77391109, 'name': 'zhengken/LyricViewDe...
# 23     {'id': 40560691, 'name': 'google/google-api-ob...
# 24     {'id': 77357924, 'name': 'fagundes/ionic-cloud...
# 25     {'id': 66231460, 'name': 'amraboelela/SwiftLev...
# 26     {'id': 77418352, 'name': 'RenantDev/TagoCMS', ...
# 27     {'id': 22378453, 'name': 'riseshia/Bonghwa', '...
# 28     {'id': 76010459, 'name': 'hesiyi/MyThread', 'u...
# 29     {'id': 77416053, 'name': 'alex1582-ccloud/Zata...
# ...                                                  ...
# 25591  {'id': 77420700, 'name': 'saiedhp/IDA-HW-1', '...
# 25592  {'id': 77427637, 'name': 'vivekjha2/datascienc...
# 25593  {'id': 77412901, 'name': 'jeanpaulsio/basecamp...
# 25594  {'id': 77416048, 'name': 'alex1582-kodicc/Wolv...
# 25595  {'id': 77429815, 'name': 'leranf/flexFun', 'ur...
# 25596  {'id': 6256729, 'name': 'JacksonTian/fks', 'ur...
# 25597  {'id': 10881451, 'name': 'dima-starosud/ElmErl...
# 25598  {'id': 38985091, 'name': 'Andersbakken/rtags-r...
# 25599  {'id': 61421257, 'name': 'eggjs/egg', 'url': '...
# 25600  {'id': 77207992, 'name': 'xingganfengxing/In-m...
# 25601  {'id': 77416041, 'name': 'jimmyjam1/Daredevil'...
# 25602  {'id': 72974961, 'name': 'taylorchen709/vueAdm...
# 25603  {'id': 9380996, 'name': 'square/java-code-styl...
# 25604  {'id': 76830923, 'name': 'qel/raquel-2016', 'u...
# 25605  {'id': 75410118, 'name': 'gbcdevelopers/GBC', ...
# 25606  {'id': 75410118, 'name': 'gbcdevelopers/GBC', ...
# 25607  {'id': 77023811, 'name': 'keonkim/awesome-bits...
# 25608  {'id': 39166950, 'name': 'AliSoftware/SwiftGen...
# 25609  {'id': 77355223, 'name': 'KawayAlpaka/bangniqi...
# 25610  {'id': 77419473, 'name': 'MacoTasu/elasticsear...
# 25611  {'id': 74431382, 'name': 'framgia/wsm_02', 'ur...
# 25612  {'id': 74431382, 'name': 'framgia/wsm_02', 'ur...
# 25613  {'id': 74431382, 'name': 'framgia/wsm_02', 'ur...
# 25614  {'id': 74431382, 'name': 'framgia/wsm_02', 'ur...
# 25615  {'id': 74431382, 'name': 'framgia/wsm_02', 'ur...
# 25616  {'id': 74431382, 'name': 'framgia/wsm_02', 'ur...
# 25617  {'id': 63947541, 'name': 'se-edu/addressbook-l...
# 25618  {'id': 63947541, 'name': 'se-edu/addressbook-l...
# 25619  {'id': 63947541, 'name': 'se-edu/addressbook-l...
# 25620  {'id': 2310495, 'name': 'ceph/ceph', 'url': 'h...
#
#                                 type
# 0                        CreateEvent
# 1                        CreateEvent
# 2                        CreateEvent
# 3                        CreateEvent
# 4                        CreateEvent
# 5                        CreateEvent
# 6                          PushEvent
# 7                        CreateEvent
# 8                        CreateEvent
# 9                        CreateEvent
# 10                       CreateEvent
# 11                       CreateEvent
# 12                  PullRequestEvent
# 13                       CreateEvent
# 14                       CreateEvent
# 15                       CreateEvent
# 16                       CreateEvent
# 17                       CreateEvent
# 18                         PushEvent
# 19                        WatchEvent
# 20                         ForkEvent
# 21                        WatchEvent
# 22                        WatchEvent
# 23                        WatchEvent
# 24                         PushEvent
# 25                         PushEvent
# 26                         PushEvent
# 27                  PullRequestEvent
# 28                         PushEvent
# 29                         PushEvent
# ...                              ...
# 25591                      PushEvent
# 25592                      PushEvent
# 25593                      PushEvent
# 25594                      PushEvent
# 25595                    CreateEvent
# 25596                     WatchEvent
# 25597                     WatchEvent
# 25598                      PushEvent
# 25599              IssueCommentEvent
# 25600                      PushEvent
# 25601                      PushEvent
# 25602                     WatchEvent
# 25603                     WatchEvent
# 25604                      PushEvent
# 25605              IssueCommentEvent
# 25606                    IssuesEvent
# 25607                     WatchEvent
# 25608                     WatchEvent
# 25609                      PushEvent
# 25610                      PushEvent
# 25611  PullRequestReviewCommentEvent
# 25612  PullRequestReviewCommentEvent
# 25613  PullRequestReviewCommentEvent
# 25614  PullRequestReviewCommentEvent
# 25615  PullRequestReviewCommentEvent
# 25616  PullRequestReviewCommentEvent
# 25617  PullRequestReviewCommentEvent
# 25618  PullRequestReviewCommentEvent
# 25619  PullRequestReviewCommentEvent
# 25620  PullRequestReviewCommentEvent
#
# [25621 rows x 8 columns]

# %%
data["actor"].loc[0]

# %%
sample = data.sample(n=672)
sample
# Out:
#                                                    actor          created_at  \
# 860    {'display_login': 'neomanic', 'login': 'neoman... 2016-12-27 05:02:01
# 24084  {'display_login': 'hiwenny', 'login': 'hiwenny... 2016-12-27 05:56:24
# 2476   {'display_login': 'muhifauzan', 'login': 'muhi... 2016-12-27 05:06:10
# 20841  {'display_login': 'cwmcallister', 'login': 'cw... 2016-12-27 05:49:18
# 25462  {'display_login': 'martindsouza', 'login': 'ma... 2016-12-27 05:59:37
# 14300  {'display_login': 'datayes-dev', 'login': 'dat... 2016-12-27 05:34:37
# 17015  {'display_login': 'wsj31013', 'login': 'wsj310... 2016-12-27 05:40:45
# 17909  {'display_login': 'RoadBytes', 'login': 'RoadB... 2016-12-27 05:42:50
# 65     {'display_login': 'kasunkv', 'login': 'kasunkv... 2016-12-27 05:00:08
# 5625   {'display_login': 'cosmeefulanito', 'login': '... 2016-12-27 05:14:13
# 12146  {'display_login': 'gxh123', 'login': 'gxh123',... 2016-12-27 05:29:49
# 13758  {'display_login': 'vollmad', 'login': 'vollmad... 2016-12-27 05:33:26
# 19772  {'display_login': 'allaudin', 'login': 'allaud... 2016-12-27 05:46:59
# 15092  {'display_login': 'pleerock', 'login': 'pleero... 2016-12-27 05:36:30
# 1881   {'display_login': 'w3yyb', 'login': 'w3yyb', '... 2016-12-27 05:04:36
# 17213  {'display_login': 'ASP1234', 'login': 'ASP1234... 2016-12-27 05:41:12
# 8932   {'display_login': 'NickAnderegg', 'login': 'Ni... 2016-12-27 05:22:13
# 3355   {'display_login': 'linAlinnnn', 'login': 'linA... 2016-12-27 05:08:23
# 23314  {'display_login': 'win-nitin', 'login': 'win-n... 2016-12-27 05:54:34
# 20307  {'display_login': 'vivekpandey12', 'login': 'v... 2016-12-27 05:48:06
# 17307  {'display_login': 'thsconline', 'login': 'thsc... 2016-12-27 05:41:24
# 17885  {'display_login': 'braz96', 'login': 'braz96',... 2016-12-27 05:42:45
# 6321   {'display_login': 'karakida', 'login': 'karaki... 2016-12-27 05:15:58
# 14103  {'display_login': 'shengmingkai', 'login': 'sh... 2016-12-27 05:34:10
# 4416   {'display_login': 'adammurdoch', 'login': 'ada... 2016-12-27 05:11:17
# 8302   {'display_login': 'peke2', 'login': 'peke2', '... 2016-12-27 05:20:53
# 22340  {'display_login': 'jsculsp', 'login': 'jsculsp... 2016-12-27 05:52:29
# 1450   {'display_login': 'sumankumar1pe', 'login': 's... 2016-12-27 05:03:23
# 20028  {'display_login': 'astrolog', 'login': 'astrol... 2016-12-27 05:47:33
# 3031   {'display_login': 'bors', 'login': 'bors', 'av... 2016-12-27 05:07:28
# ...                                                  ...                 ...
# 18113  {'display_login': 'biluo62', 'login': 'biluo62... 2016-12-27 05:43:17
# 1869   {'display_login': 'GregoryIan', 'login': 'Greg... 2016-12-27 05:04:35
# 12659  {'display_login': 'k2mno5', 'login': 'k2mno5',... 2016-12-27 05:30:57
# 15448  {'display_login': 'lnshi', 'login': 'lnshi', '... 2016-12-27 05:37:12
# 4836   {'display_login': 'arunkbharathan', 'login': '... 2016-12-27 05:12:22
# 2370   {'display_login': 'jameskolce', 'login': 'jame... 2016-12-27 05:05:52
# 9696   {'display_login': 'ValentinAndreev', 'login': ... 2016-12-27 05:24:05
# 15323  {'display_login': 'kaleozhou', 'login': 'kaleo... 2016-12-27 05:36:58
# 2559   {'display_login': 'sonofjack', 'login': 'sonof... 2016-12-27 05:06:22
# 692    {'display_login': 'steveoc64', 'login': 'steve... 2016-12-27 05:01:37
# 19756  {'display_login': 'marioaburto10', 'login': 'm... 2016-12-27 05:46:56
# 1231   {'display_login': 'chmielu24', 'login': 'chmie... 2016-12-27 05:02:51
# 5998   {'display_login': 'tecknork', 'login': 'teckno... 2016-12-27 05:15:14
# 8436   {'display_login': 'gaoweibupt', 'login': 'gaow... 2016-12-27 05:21:11
# 5163   {'display_login': 'sami10015', 'login': 'sami1... 2016-12-27 05:13:07
# 16410  {'display_login': 'yfdyh000', 'login': 'yfdyh0... 2016-12-27 05:39:24
# 15408  {'display_login': 'pedmands', 'login': 'pedman... 2016-12-27 05:37:08
# 25245  {'display_login': 'NikitaAgafonov', 'login': '... 2016-12-27 05:59:03
# 3739   {'display_login': 'jwhitcraft', 'login': 'jwhi... 2016-12-27 05:09:25
# 5292   {'display_login': 'UnforeseenOcean', 'login': ... 2016-12-27 05:13:25
# 13359  {'display_login': 'TAHRDNO1', 'login': 'TAHRDN... 2016-12-27 05:32:34
# 1435   {'display_login': 'BoSicle', 'login': 'BoSicle... 2016-12-27 05:03:19
# 19773  {'display_login': 'fabianLeon', 'login': 'fabi... 2016-12-27 05:46:59
# 14544  {'display_login': 'Jackeagle', 'login': 'Jacke... 2016-12-27 05:35:07
# 17560  {'display_login': 'DaisukeOno', 'login': 'Dais... 2016-12-27 05:41:59
# 638    {'display_login': 'mackworth', 'login': 'mackw... 2016-12-27 05:01:29
# 9770   {'display_login': 'walkman4321', 'login': 'wal... 2016-12-27 05:24:15
# 12048  {'display_login': 'weiwangblog', 'login': 'wei... 2016-12-27 05:29:35
# 23944  {'display_login': 'mdi-odoo', 'login': 'mdi-od... 2016-12-27 05:56:02
# 5144   {'display_login': 'zosman1', 'login': 'zosman1... 2016-12-27 05:13:04
#
#                id                                                org  \
# 860    5072952330                                                NaN
# 24084  5073046922                                                NaN
# 2476   5072959542                                                NaN
# 20841  5073033630                                                NaN
# 25462  5073052978                                                NaN
# 14300  5073007402                                                NaN
# 17015  5073018375                                                NaN
# 17909  5073022087                                                NaN
# 65     5072948951                                                NaN
# 5625   5072972668                                                NaN
# 12146  5072998822                                                NaN
# 13758  5073005292                                                NaN
# 19772  5073029363                                                NaN
# 15092  5073010755  {'id': 20165699, 'avatar_url': 'https://avatar...
# 1881   5072956967  {'id': 6066761, 'avatar_url': 'https://avatars...
# 17213  5073019182                                                NaN
# 8932   5072986253                                                NaN
# 3355   5072963210                                                NaN
# 23314  5073043450                                                NaN
# 20307  5073031382                                                NaN
# 17307  5073019548                                                NaN
# 17885  5073021942                                                NaN
# 6321   5072975379                                                NaN
# 14103  5073006656                                                NaN
# 4416   5072967928  {'id': 124156, 'avatar_url': 'https://avatars....
# 8302   5072983895                                                NaN
# 22340  5073039582                                                NaN
# 1450   5072954964                                                NaN
# 20028  5073030340                                                NaN
# 3031   5072961674  {'id': 5430905, 'avatar_url': 'https://avatars...
# ...           ...                                                ...
# 18113  5073022977                                                NaN
# 1869   5072956941  {'id': 11855343, 'avatar_url': 'https://avatar...
# 12659  5073000860                                                NaN
# 15448  5073012001  {'id': 730467, 'avatar_url': 'https://avatars....
# 4836   5072969613                                                NaN
# 2370   5072959046                                                NaN
# 9696   5072989405                                                NaN
# 15323  5073011537                                                NaN
# 2559   5072959846  {'id': 9441414, 'avatar_url': 'https://avatars...
# 692    5072951679                                                NaN
# 19756  5073029305                                                NaN
# 1231   5072953902                                                NaN
# 5998   5072974153                                                NaN
# 8436   5072984401                                                NaN
# 5163   5072970787                                                NaN
# 16410  5073016002                                                NaN
# 15408  5073011863  {'id': 1617169, 'avatar_url': 'https://avatars...
# 25245  5073051968                                                NaN
# 3739   5072964829  {'id': 9343010, 'avatar_url': 'https://avatars...
# 5292   5072971307                                                NaN
# 13359  5073003692                                                NaN
# 1435   5072954864  {'id': 6175168, 'avatar_url': 'https://avatars...
# 19773  5073029365                                                NaN
# 14544  5073008260                                                NaN
# 17560  5073020536                                                NaN
# 638    5072951443                                                NaN
# 9770   5072989688  {'id': 3584568, 'avatar_url': 'https://avatars...
# 12048  5072998394                                                NaN
# 23944  5073046253  {'id': 7466976, 'avatar_url': 'https://avatars...
# 5144   5072970726                                                NaN
#
#                                                  payload public  \
# 860    {'action': 'opened', 'issue': {'assignees': []...   True
# 24084  {'ref': 'refs/heads/master', 'push_id': 147385...   True
# 2476   {'pull_request': {'milestone': None, 'html_url...   True
# 20841  {'pull_request': {'milestone': None, 'html_url...   True
# 25462  {'ref': 'refs/heads/gh-pages', 'push_id': 1473...   True
# 14300  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 17015  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 17909  {'pull_request': {'milestone': None, 'html_url...   True
# 65     {'ref': 'master', 'ref_type': 'branch', 'maste...   True
# 5625   {'ref': 'refs/heads/master', 'push_id': 147383...   True
# 12146  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 13758  {'ref': 'master', 'ref_type': 'branch', 'maste...   True
# 19772  {'ref': 'refs/heads/master', 'push_id': 147385...   True
# 15092  {'pull_request': {'milestone': None, 'html_url...   True
# 1881                               {'action': 'started'}   True
# 17213                              {'action': 'started'}   True
# 8932                                                  {}   True
# 3355   {'ref': None, 'ref_type': 'repository', 'maste...   True
# 23314  {'ref': None, 'ref_type': 'repository', 'maste...   True
# 20307  {'ref': 'refs/heads/master', 'push_id': 147385...   True
# 17307  {'ref': 'refs/heads/gh-pages', 'push_id': 1473...   True
# 17885  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 6321   {'pull_request': {'milestone': None, 'html_url...   True
# 14103                              {'action': 'started'}   True
# 4416   {'action': 'opened', 'issue': {'assignees': []...   True
# 8302   {'ref': 'refs/heads/master', 'push_id': 147383...   True
# 22340  {'ref': 'refs/heads/master', 'push_id': 147385...   True
# 1450   {'ref': None, 'ref_type': 'repository', 'maste...   True
# 20028  {'ref': 'refs/heads/gh-pages', 'push_id': 1473...   True
# 3031   {'ref': 'refs/heads/auto', 'push_id': 14738280...   True
# ...                                                  ...    ...
# 18113  {'ref': 'refs/heads/master', 'push_id': 147385...   True
# 1869   {'pull_request': {'milestone': None, 'html_url...   True
# 12659  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 15448                              {'action': 'started'}   True
# 4836   {'ref': 'refs/heads/master', 'push_id': 147383...   True
# 2370   {'comment': {'updated_at': '2016-12-27T05:05:5...   True
# 9696   {'pull_request': {'milestone': None, 'html_url...   True
# 15323  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 2559                               {'action': 'started'}   True
# 692    {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 19756  {'ref': 'refs/heads/master', 'push_id': 147385...   True
# 1231   {'ref': 'refs/heads/master', 'push_id': 147382...   True
# 5998   {'ref': 'refs/heads/master', 'push_id': 147383...   True
# 8436   {'ref': 'refs/heads/master', 'push_id': 147383...   True
# 5163   {'ref': None, 'ref_type': 'repository', 'maste...   True
# 16410  {'action': 'closed', 'issue': {'assignees': []...   True
# 15408                              {'action': 'started'}   True
# 25245  {'ref': 'refs/heads/master', 'push_id': 147386...   True
# 3739   {'comment': {'updated_at': '2016-12-27T05:09:2...   True
# 5292   {'forkee': {'public': True, 'assignees_url': '...   True
# 13359  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 1435   {'action': 'opened', 'issue': {'assignees': []...   True
# 19773  {'ref': 'refs/heads/master', 'push_id': 147385...   True
# 14544  {'ref': 'ramdisk', 'ref_type': 'branch', 'mast...   True
# 17560  {'pull_request': {'milestone': None, 'html_url...   True
# 638    {'comment': {'updated_at': '2016-12-27T05:01:2...   True
# 9770   {'action': 'opened', 'issue': {'assignees': []...   True
# 12048  {'ref': 'refs/heads/master', 'push_id': 147384...   True
# 23944  {'ref': 'refs/heads/master-stock-new-configura...   True
# 5144   {'ref': 'refs/heads/master', 'push_id': 147383...   True
#
#                                                     repo  \
# 860    {'id': 50800659, 'name': 'Izhido/Quake_For_OSX...
# 24084  {'id': 76756792, 'name': 'hiwenny/python-tradi...
# 2476   {'id': 72477894, 'name': 'danielberkompas/dest...
# 20841  {'id': 77427887, 'name': 'cwmcallister/hello-w...
# 25462  {'id': 77289076, 'name': 'martindsouza/talkape...
# 14300  {'id': 76622604, 'name': 'datayes-dev/robotMob...
# 17015  {'id': 73333733, 'name': 'wsj31013/Python', 'u...
# 17909  {'id': 77253740, 'name': 'RoadBytes/BabyNamer'...
# 65     {'id': 77426934, 'name': 'kasunkv/Training-Man...
# 5625   {'id': 77427473, 'name': 'cosmeefulanito/proto...
# 12146  {'id': 77427717, 'name': 'gxh123/picture', 'ur...
# 13758  {'id': 77428315, 'name': 'vollmad/Box2D-D', 'u...
# 19772  {'id': 77398409, 'name': 'allaudin/water', 'ur...
# 15092  {'id': 52773157, 'name': 'typeorm/typeorm', 'u...
# 1881   {'id': 14895052, 'name': 'container-interop/co...
# 17213  {'id': 76383569, 'name': 'lk-geimfari/awesomeo...
# 8932   {'id': 77309306, 'name': 'NickAnderegg/docker-...
# 3355   {'id': 77427267, 'name': 'linAlinnnn/Ant-Run',...
# 23314  {'id': 77429682, 'name': 'win-nitin/cozyfashio...
# 20307  {'id': 76024482, 'name': 'masagatech/erpv1', '...
# 17307  {'id': 53823042, 'name': 'thsconline/s', 'url'...
# 17885  {'id': 27470349, 'name': 'braz96/skin.mimic', ...
# 6321   {'id': 70128784, 'name': 'ryohalon/ZooGame', '...
# 14103  {'id': 77385489, 'name': 'wepe/O2O-Coupon-Usag...
# 4416   {'id': 65175263, 'name': 'gradle/gradle-profil...
# 8302   {'id': 76431327, 'name': 'peke2/test_python', ...
# 22340  {'id': 72084252, 'name': 'jsculsp/tango_with_d...
# 1450   {'id': 77427066, 'name': 'sumankumar1pe/sample...
# 20028  {'id': 75277433, 'name': 'astrolog/repo', 'url...
# 3031   {'id': 724712, 'name': 'rust-lang/rust', 'url'...
# ...                                                  ...
# 18113  {'id': 74194827, 'name': 'biluo62/WechatOAuth'...
# 1869   {'id': 63995402, 'name': 'pingcap/docs', 'url'...
# 12659  {'id': 77424237, 'name': 'k2mno5/CS-225-Lec', ...
# 15448  {'id': 1283503, 'name': 'request/request', 'ur...
# 4836   {'id': 77051421, 'name': 'arunkbharathan/node-...
# 2370   {'id': 7212645, 'name': 'syl20bnr/spacemacs', ...
# 9696   {'id': 73261209, 'name': 'ValentinAndreev/flas...
# 15323  {'id': 76418805, 'name': 'kaleozhou/okrobot2.0...
# 2559   {'id': 36551995, 'name': 'react-component/drop...
# 692    {'id': 77418238, 'name': 'steveoc64/gopher-cou...
# 19756  {'id': 76123570, 'name': 'marioaburto10/Profes...
# 1231   {'id': 76288871, 'name': 'chmielu24/Tetris', '...
# 5998   {'id': 77295577, 'name': 'tecknork/MeanSample'...
# 8436   {'id': 77060385, 'name': 'gaoweibupt/gaoweibup...
# 5163   {'id': 77427483, 'name': 'sami10015/Meadowlark...
# 16410  {'id': 23628824, 'name': 'yfdyh000/tabutils', ...
# 15408  {'id': 8424040, 'name': 'processing/p5.js', 'u...
# 25245  {'id': 76774861, 'name': 'NikitaAgafonov/galle...
# 3739   {'id': 26337322, 'name': 'rancher/rancher', 'u...
# 5292   {'id': 45342735, 'name': 'Huimieer/RKExposer',...
# 13359  {'id': 77428079, 'name': 'TAHRDNO1/TAHRDNO1.gi...
# 1435   {'id': 17914657, 'name': 'webcompat/web-bugs',...
# 19773  {'id': 77173070, 'name': 'fabianLeon/fabianLeo...
# 14544  {'id': 77315859, 'name': 'Jackeagle/lenovo', '...
# 17560  {'id': 76086659, 'name': 'DaisukeOno/trippiece...
# 638    {'id': 13279041, 'name': 'dscottbuch/cTiVo', '...
# 9770   {'id': 13831185, 'name': 'libimobiledevice/ide...
# 12048  {'id': 38519587, 'name': 'weiwangblog/weiwangb...
# 23944  {'id': 19853934, 'name': 'odoo-dev/odoo', 'url...
# 5144   {'id': 77354864, 'name': 'zosman1/zosman1.gith...
#
#                                 type
# 860                      IssuesEvent
# 24084                      PushEvent
# 2476   PullRequestReviewCommentEvent
# 20841               PullRequestEvent
# 25462                      PushEvent
# 14300                      PushEvent
# 17015                      PushEvent
# 17909               PullRequestEvent
# 65                       CreateEvent
# 5625                       PushEvent
# 12146                      PushEvent
# 13758                    CreateEvent
# 19772                      PushEvent
# 15092  PullRequestReviewCommentEvent
# 1881                      WatchEvent
# 17213                     WatchEvent
# 8932                     PublicEvent
# 3355                     CreateEvent
# 23314                    CreateEvent
# 20307                      PushEvent
# 17307                      PushEvent
# 17885                      PushEvent
# 6321                PullRequestEvent
# 14103                     WatchEvent
# 4416                     IssuesEvent
# 8302                       PushEvent
# 22340                      PushEvent
# 1450                     CreateEvent
# 20028                      PushEvent
# 3031                       PushEvent
# ...                              ...
# 18113                      PushEvent
# 1869                PullRequestEvent
# 12659                      PushEvent
# 15448                     WatchEvent
# 4836                       PushEvent
# 2370               IssueCommentEvent
# 9696                PullRequestEvent
# 15323                      PushEvent
# 2559                      WatchEvent
# 692                        PushEvent
# 19756                      PushEvent
# 1231                       PushEvent
# 5998                       PushEvent
# 8436                       PushEvent
# 5163                     CreateEvent
# 16410                    IssuesEvent
# 15408                     WatchEvent
# 25245                      PushEvent
# 3739               IssueCommentEvent
# 5292                       ForkEvent
# 13359                      PushEvent
# 1435                     IssuesEvent
# 19773                      PushEvent
# 14544                    CreateEvent
# 17560               PullRequestEvent
# 638                IssueCommentEvent
# 9770                     IssuesEvent
# 12048                      PushEvent
# 23944                      PushEvent
# 5144                       PushEvent
#
# [672 rows x 8 columns]

# %%
reqRate = requests.get("https://api.github.com/rate_limit?client_id=9d242c79a529faace6ac&client_secret=55564bfcfbf17fd4da9b73ef4478ac2682579855")
reqRate.json()
# Out:
# {'rate': {'limit': 5000, 'remaining': 5000, 'reset': 1495520150},
#  'resources': {'core': {'limit': 5000, 'remaining': 5000, 'reset': 1495520150},
#   'graphql': {'limit': 5000, 'remaining': 5000, 'reset': 1495520150},
#   'search': {'limit': 30, 'remaining': 30, 'reset': 1495516610}}}

# %%
geolocator = Nominatim()

# %%
location = geolocator.geocode("Stanford, CA")

# %%
location.address
# Out:
# 'Stanford University, Santa Clara County, California, United States of America'

# %%
print((location.latitude, location.longitude))
# Out:
# (37.4265649, -122.170187551249)

# %%
location.raw
# Out:
# {'boundingbox': ['37.40632', '37.4469336', '-122.1913193', '-122.1492399'],
#  'class': 'boundary',
#  'display_name': 'Stanford University, Santa Clara County, California, United States of America',
#  'icon': 'https://nominatim.openstreetmap.org/images/mapicons/poi_boundary_administrative.p.20.png',
#  'importance': 0.83540146768924,
#  'lat': '37.4265649',
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://www.openstreetmap.org/copyright',
#  'lon': '-122.170187551249',
#  'osm_id': '1546085',
#  'osm_type': 'relation',
#  'place_id': '159366533',
#  'type': 'administrative'}

# %% [markdown]
# We want to have 0.5 million rows, where each row corresponds to an event. Each row requires 2 api calls. 1000000 / 31 = 32259 calls per day, so 32259 / 24 = 1345 calls per hour, so a random sample of 672 events from every hour.

# %%
import calendar
import time
import os
import datetime

# %%
calendar.timegm(time.gmtime())
# Out:
# 1495575360

# %%
def updateResetTime(clientApp):
    req = requests.get("https://api.github.com/rate_limit?" + clientApp["target"])
    clientApp["resetTime"] = req.json()["resources"]["core"]["reset"]
    
def updateRemaining(clientApp):
    reqRate = requests.get("https://api.github.com/rate_limit?" + clientApp["target"])
    clientApp["callsRemaining"] = reqRate.json()["resources"]["core"]["remaining"]

# %%
req = requests.get("https://api.github.com/rate_limit?client_id=4edea2a6d8c445bb025a&client_secret=2e93bdc408bb1beaf84610bab917487e8674259c")
req.json()
# Out:
# {'rate': {'limit': 5000, 'remaining': 3091, 'reset': 1495609198},
#  'resources': {'core': {'limit': 5000, 'remaining': 3091, 'reset': 1495609198},
#   'graphql': {'limit': 5000, 'remaining': 5000, 'reset': 1495611115},
#   'search': {'limit': 30, 'remaining': 30, 'reset': 1495607575}}}

# %%
clientApps = []
currentAppIndex = 0
#register each app
for i in range(1):#len(auth)):
    clientApp = "client_id=" + auth["Client ID"].loc[i] + "&client_secret=" + auth["Client Secret"].loc[i]
    clientApp = {
            "target": clientApp,
            "resetTime": None,
            "callsRemaining": 5000
        }
    updateResetTime(clientApp)
    updateRemaining(clientApp)
    clientApps.append(clientApp)

# %%
def findNextApp():
    global clientApps
    global currentAppIndex
    
    count = 0
    found = [False, clientApps[currentAppIndex]["resetTime"]] #Did we find one, and if not, what is min reset time?
    minIndex = currentAppIndex
    currentTime = calendar.timegm(time.gmtime())
    # loop: look at the other 3? apps to see which one should be used next
    while True:
        count += 1
        if (count == len(clientApps)):
            break
            
        if currentAppIndex == len(clientApps) - 1:
            currentAppIndex = 0
        else:
            currentAppIndex += 1
            
        clientApp = clientApps[currentAppIndex]
        updateRemaining(clientApp)
        updateResetTime(clientApp)
        
        if found[1] > clientApp["resetTime"]:
            found[1] = clientApp["resetTime"]
            minIndex = currentAppIndex
        if clientApp["callsRemaining"] > 0:
            found[0] = True
            print("switched to app: " + str(currentAppIndex))
            break
    found[1] -= currentTime #To give the the number of seconds to sleep
    if found[0] == False:
        currentAppIndex = minIndex
        print("sleep for: " + str(found[1] + 60))
        time.sleep(found[1] + 60)
        print("wake up")
        updateRemaining(clientApps[currentAppIndex])
        updateResetTime(clientApps[currentAppIndex])
    
def makeCall(url):
    global clientApps
    global currentAppIndex
    #time.sleep(0.1)
    clientApp = clientApps[currentAppIndex]
    updateRemaining(clientApp)
    
    if (clientApp["callsRemaining"] == 0):
        updateResetTime(clientApp)
        found = findNextApp()      
            
    clientApp = clientApps[currentAppIndex]
    updateRemaining(clientApp)
    req = requests.get(url + "?" + clientApp["target"])
    clientApp["callsRemaining"] -= 1
    
    res = req.json()
    if "location" not in res:
        res["location"] = None
    if "created_at" not in res:
        res["created_at"] = None
    if "login" not in res:
        res["login"] = None
    if "name" not in res:
        res["name"] = None
    if "company" not in res:
        res["company"] = None
    if "hireable" not in res:
        res["hireable"] = None
    if "language" not in res:
        res["language"] = None
    if "size" not in res:
        res["size"] = None
    return res

# %%
clientApps
# Out:
# [{'callsRemaining': 5000,
#   'resetTime': 1496014006,
#   'target': 'client_id=b5c50ad1587cb08e035c&client_secret=03b0260a14331870d4430700973a0c07eea3b9cd'}]

# %%
# Out:
# 1

# %%
# we need to loop every hour, obtaining 672 randoms from each
docs = {}
path = "/share/GithubAnalysis"
filenames = []
for filename in os.listdir(path):
    if filename != "called":
        filenames.append(filename)
            
            
data = pd.Series(filenames)
data
# Out:
# 0       2016-12-27-5.json
# 1       2016-12-31-1.json
# 2       2016-12-19-1.json
# 3       2016-12-07-5.json
# 4      2016-12-01-21.json
# 5      2016-12-05-11.json
# 6       2016-12-04-2.json
# 7      2016-12-13-21.json
# 8       2016-12-22-7.json
# 9       2016-12-10-3.json
# 10     2016-12-26-15.json
# 11     2016-12-10-21.json
# 12     2016-12-25-15.json
# 13      2016-12-08-2.json
# 14     2016-12-03-20.json
# 15      2016-12-12-3.json
# 16     2016-12-11-20.json
# 17     2016-12-12-13.json
# 18      2016-12-17-9.json
# 19     2016-12-27-17.json
# 20     2016-12-12-19.json
# 21     2016-12-05-18.json
# 22     2016-12-26-17.json
# 23      2016-12-11-3.json
# 24     2016-12-17-14.json
# 25      2016-12-16-5.json
# 26      2016-12-17-6.json
# 27      2016-12-01-9.json
# 28      2016-12-15-1.json
# 29      2016-12-18-5.json
#               ...
# 714    2016-12-09-22.json
# 715    2016-12-22-20.json
# 716    2016-12-25-11.json
# 717     2016-12-29-2.json
# 718    2016-12-03-11.json
# 719    2016-12-12-21.json
# 720     2016-12-12-9.json
# 721    2016-12-25-16.json
# 722     2016-12-27-0.json
# 723    2016-12-07-21.json
# 724     2016-12-13-8.json
# 725     2016-12-09-4.json
# 726    2016-12-03-12.json
# 727     2016-12-01-0.json
# 728    2016-12-21-11.json
# 729     2016-12-29-9.json
# 730    2016-12-20-16.json
# 731    2016-12-22-15.json
# 732     2016-12-26-1.json
# 733    2016-12-12-22.json
# 734    2016-12-03-21.json
# 735     2016-12-20-2.json
# 736    2016-12-24-11.json
# 737    2016-12-18-10.json
# 738     2016-12-30-2.json
# 739     2016-12-15-3.json
# 740     2016-12-16-0.json
# 741     2016-12-24-0.json
# 742     2016-12-17-2.json
# 743    2016-12-30-21.json
# dtype: object

# %%
for i in range(259, len(filenames)):
    filename = filenames[i]
    data = pd.read_json("/share/GithubAnalysis/" + filename, lines=True)
    sample = data.sample(n=672)
    
    print("\n" + str(i) + ": " + filename)
    langSeries = []
    sizeSeries = []
    
    locationSeries = []
    createdAtSeries = []
    loginSeries = []
    nameSeries = []
    companySeries = []
    hireableSeries = []
    
    for j in range(len(sample)):
        sys.stdout.write("\r - %i" % j)
        sys.stdout.flush()
        
        actor = sample["actor"].iloc[j]
        actorReq = makeCall(actor["url"])
        locationSeries.append(actorReq["location"])
        createdAtSeries.append(actorReq["created_at"])
        loginSeries.append(actorReq["login"])
        nameSeries.append(actorReq["name"])
        companySeries.append(actorReq["company"])
        hireableSeries.append(actorReq["hireable"])
        
        repo = sample["repo"].iloc[j]
        repoReq = makeCall(repo["url"])
        langSeries.append(repoReq["language"])
        sizeSeries.append(repoReq["size"])
        
    seriesDf = pd.DataFrame({
        "language": langSeries,
        "size": sizeSeries,
        "location": locationSeries,
        "created_at": createdAtSeries,
        "login": loginSeries,
        "name": nameSeries,
        "company": companySeries,
        "hireable": hireableSeries
    })
    seriesDf.to_csv("/share/GithubAnalysis/called/" + filename.rstrip(".json") + ".csv", sep=",")
    
print("DONE!")
# Out:
# 233: 2016-12-09-23.json
#  - 671
# 234: 2016-12-29-5.json
#  - 671
# 235: 2016-12-04-10.json
#  - 671
# 236: 2016-12-10-13.json
#  - 72
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385                     # otherwise it looks like a programming error was the cause.
# --> 386                     six.raise_from(e, None)
#     387         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#
# /opt/conda/lib/python3.5/http/client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# /opt/conda/lib/python3.5/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /opt/conda/lib/python3.5/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /opt/conda/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648             retries = retries.increment(method, url, error=e, _pool=self,
# --> 649                                         _stacktrace=sys.exc_info()[2])
#     650             retries.sleep()
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     346             if read is False or not self._is_method_retryable(method):
# --> 347                 raise six.reraise(type(error), error, _stacktrace)
#     348             elif read is not None:
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385                     # otherwise it looks like a programming error was the cause.
# --> 386                     six.raise_from(e, None)
#     387         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/conda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#
# /opt/conda/lib/python3.5/http/client.py in getresponse(self)
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#
# /opt/conda/lib/python3.5/http/client.py in begin(self)
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#
# /opt/conda/lib/python3.5/http/client.py in _read_status(self)
#     265             # sending a valid response.
# --> 266             raise RemoteDisconnected("Remote end closed connection without"
#     267                                      " response")
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-112-45579d43f11c> in <module>()
#      20
#      21         actor = sample["actor"].iloc[j]
# ---> 22         actorReq = makeCall(actor["url"])
#      23         locationSeries.append(actorReq["location"])
#      24         createdAtSeries.append(actorReq["created_at"])
#
# <ipython-input-102-67729a04a9e8> in makeCall(url)
#      51     clientApp = clientApps[currentAppIndex]
#      52     updateRemaining(clientApp)
# ---> 53     req = requests.get(url + "?" + clientApp["target"])
#      54     clientApp["callsRemaining"] -= 1
#      55
#
# /opt/conda/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /opt/conda/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /opt/conda/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /opt/conda/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /opt/conda/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     471
#     472         except (ProtocolError, socket.error) as err:
# --> 473             raise ConnectionError(err, request=request)
#     474
#     475         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response',))

# %%
test = pd.read_csv("/share/GithubAnalysis/called/2016-12-04-2.csv", index_col=0)

# %%
test
# Out:
#                       company            created_at hireable  \
# 0                         NaN  2013-11-04T01:00:42Z      NaN
# 1                         NaN  2008-09-28T01:10:20Z     True
# 2                         NaN  2014-04-28T15:18:20Z      NaN
# 3                         NaN  2015-04-21T05:15:12Z      NaN
# 4                         NaN  2016-01-31T12:21:52Z     True
# 5                         NaN  2015-08-16T08:23:32Z      NaN
# 6                         NaN  2016-03-04T20:49:08Z      NaN
# 7                         NaN  2013-11-26T16:25:18Z      NaN
# 8           Machine Dynamics.  2013-08-22T06:56:32Z      NaN
# 9                         NaN  2014-05-29T09:31:00Z      NaN
# 10                        NaN  2015-02-25T06:28:58Z      NaN
# 11   Lombiq Technologies Ltd.  2014-08-21T21:37:45Z      NaN
# 12                        NaN  2016-12-04T02:34:03Z      NaN
# 13                        NaN  2013-01-09T14:39:27Z      NaN
# 14                        NaN  2015-05-04T18:48:20Z      NaN
# 15   Lombiq Technologies Ltd.  2014-08-21T21:37:45Z      NaN
# 16                        NaN  2016-12-04T00:56:09Z      NaN
# 17                        NaN  2014-09-30T17:45:52Z      NaN
# 18                        NaN  2015-07-31T08:33:42Z      NaN
# 19                        NaN  2015-09-15T22:05:53Z     True
# 20                        NaN  2013-08-12T06:12:01Z     True
# 21                        NaN  2015-09-16T19:35:02Z      NaN
# 22      @Huawei  @opentracing  2013-09-12T07:04:16Z     True
# 23                        NaN  2016-03-03T00:05:21Z      NaN
# 24                        NaN  2016-03-19T00:19:06Z      NaN
# 25              OfferUp, Inc.  2014-02-12T22:32:32Z      NaN
# 26                        NaN  2015-08-10T18:08:53Z     True
# 27                        NaN  2016-09-05T20:46:01Z      NaN
# 28                        NaN  2013-02-20T23:09:31Z      NaN
# 29                        NaN  2016-12-04T02:38:07Z      NaN
# ..                        ...                   ...      ...
# 642                       NaN  2008-04-05T20:24:37Z     True
# 643         Peking University  2016-08-11T14:20:51Z      NaN
# 644                       NaN  2013-03-01T18:13:35Z      NaN
# 645                       NaN  2015-06-29T12:41:18Z      NaN
# 646                       NaN  2014-05-27T09:36:57Z     True
# 647  PostgreSQL International  2010-09-19T00:11:44Z      NaN
# 648                       NaN  2015-05-08T22:18:19Z      NaN
# 649                       NaN  2016-10-07T06:21:44Z     True
# 650                       NaN  2016-12-04T01:59:04Z      NaN
# 651                       NaN  2009-07-03T10:34:32Z      NaN
# 652                       NaN  2016-08-09T15:59:46Z      NaN
# 653                       NaN  2016-11-21T22:34:39Z      NaN
# 654                       NaN  2013-12-10T01:34:23Z      NaN
# 655                       NaN  2013-08-14T16:17:42Z     True
# 656                       NaN  2012-10-23T20:21:56Z      NaN
# 657                       NaN  2016-09-15T17:42:51Z      NaN
# 658                       NaN  2016-08-20T11:23:02Z      NaN
# 659                       HEU  2016-04-13T09:55:56Z      NaN
# 660                       NaN  2016-09-28T00:22:14Z      NaN
# 661                       NaN  2014-09-25T03:06:58Z      NaN
# 662                       NaN  2016-09-13T09:23:30Z      NaN
# 663                       NaN  2014-03-26T17:22:21Z      NaN
# 664  Lombiq Technologies Ltd.  2014-08-21T21:37:45Z      NaN
# 665                       NaN  2015-05-08T22:18:19Z      NaN
# 666                       NaN  2016-08-10T03:36:32Z      NaN
# 667                 Bytedance  2014-05-06T12:09:18Z      NaN
# 668                       NaN  2012-02-28T13:48:19Z     True
# 669                       NaN  2013-02-25T21:23:29Z      NaN
# 670                       NaN  2016-05-25T22:41:54Z     True
# 671                       NaN  2015-01-02T09:50:42Z      NaN
#
#              language                location                           login  \
# 0                 PHP                     NaN                           pdarg
# 1                 PHP                     NaN                   renatomarinho
# 2                Java              Everywhere                      CrackerTeg
# 3                HTML                     NaN                          pshyam
# 4          JavaScript         Germany, Berlin                       edenreich
# 5                Java                     NaN                    Morpheus1992
# 6              Python                     NaN                      0xbadc0de1
# 7              Python                     NaN                         whoburg
# 8                   C          shenzhen,china                          Lschen
# 9          JavaScript                     NaN                       tbfungeek
# 10             Python                     NaN                      lmh1020lmh
# 11                 C#       Budapest, Hungary                       LombiqBot
# 12               Java                     NaN                       ElsiePete
# 13                C++                     NaN                       digimatic
# 14               HTML                     NaN                         jshatch
# 15                 C#       Budapest, Hungary                       LombiqBot
# 16                CSS                     NaN                     Vojtapetrus
# 17         JavaScript                     NaN                          clett1
# 18               Java                     NaN                          Nansir
# 19             Matlab                     NaN                          kjosh9
# 20                NaN                  Canada                         gorango
# 21                 C#                     NaN                       multidila
# 22               Java          Beijing, China                        wu-sheng
# 23                NaN                     NaN                     DictatorDan
# 24               HTML                     NaN                        Rosho123
# 25                  C                     NaN                         opragel
# 26                CSS  Richmond Hill, Ontario                          kipply
# 27         JavaScript                     NaN                        cletus93
# 28                NaN           Glendale , CA                        sarmen22
# 29               Java                     NaN                   MollCharlotte
# ..                ...                     ...                             ...
# 642           Haskell             Madison, WI                         mcandre
# 643  Jupyter Notebook      Beijing, P.R.China                       LiYunyang
# 644               C++                     NaN                      agostini01
# 645              Java                     NaN               tylerthedeveloper
# 646               NaN      ShenZhen GuangDong                          panxl6
# 647               NaN                  Canada                      davecramer
# 648               NaN                     NaN               CodePipeline-Test
# 649  Jupyter Notebook                  Bremen                          tohahn
# 650               NaN                     NaN                          JJ1616
# 651            Python          Quebec, Canada                          legege
# 652               NaN                     NaN                atomist-test-web
# 653              Ruby                     NaN  homebrew-version-migration-bot
# 654               PHP                     NaN                        jansilvo
# 655            Python      Marina del Rey, CA                    awentzonline
# 656             Shell                     NaN                          slacka
# 657        JavaScript                     NaN                       justin-ly
# 658                 C                     NaN                       musclelee
# 659              HTML                  harbin                      daisyliudi
# 660              HTML                     NaN                    CollinPJones
# 661              GLSL                     NaN                   IrvingDeJesus
# 662        JavaScript                      ☁️                speedtracker-bot
# 663                 C                     NaN                         kuanyao
# 664                C#       Budapest, Hungary                       LombiqBot
# 665               NaN                     NaN               CodePipeline-Test
# 666        JavaScript                     NaN                   allanjmartell
# 667                Go                 Beijing                          qw4990
# 668             Shell      Cedar Rapids, Iowa                     ryanniehaus
# 669              HTML             Seattle, WA                        hmvantol
# 670        JavaScript            Boise, Idaho                    mwolfhoffman
# 671               NaN                     NaN                       clairemao
#
#                          name      size
# 0                       Peter    5176.0
# 1              Renato Marinho   16723.0
# 2         Jonathan Zuniga "Z"   28812.0
# 3                         NaN   10565.0
# 4                  Eden Reich      19.0
# 5                         NaN    2600.0
# 6                         NaN       2.0
# 7               Warren Hoburg   38219.0
# 8                  chris-chan   14414.0
# 9                 Xiaohai.lin    7396.0
# 10                        NaN   62056.0
# 11                 Lombiq Bot     160.0
# 12                        NaN       5.0
# 13                        NaN  245801.0
# 14                        NaN   30762.0
# 15                 Lombiq Bot      35.0
# 16                        NaN    2640.0
# 17                        NaN  127409.0
# 18                     Mr zhu     210.0
# 19            Joshua Knestaut  552252.0
# 20           Goran Spasojevic       NaN
# 21                        NaN   29799.0
# 22                吴晟 Wu Sheng  140789.0
# 23                        NaN   85543.0
# 24                        NaN    2368.0
# 25                Owen Pragel   68215.0
# 26                 Carol Chen   13576.0
# 27                        NaN   16338.0
# 28           Sarmen Pirageneh       NaN
# 29                        NaN       5.0
# ..                        ...       ...
# 642         Andrew Pennebaker    2636.0
# 643                Yunyang Li  435076.0
# 644          Nicolas Agostini    3954.0
# 645                       NaN    1286.0
# 646                       潘兴龙       NaN
# 647               Dave Cramer    8971.0
# 648                       NaN       3.0
# 649               Tobias Hahn   29787.0
# 650                       NaN       0.0
# 651  Georges-Etienne Legendre    1651.0
# 652                       NaN       NaN
# 653                       NaN    2045.0
# 654                       NaN     969.0
# 655                Adam Wentz    4476.0
# 656                       NaN   13095.0
# 657                 Justin Ly      10.0
# 658                       Lee  188854.0
# 659                     cindy     911.0
# 660                       NaN   10633.0
# 661                       NaN  161860.0
# 662              SpeedTracker    1205.0
# 663                  Kuan Yao      15.0
# 664                Lombiq Bot      25.0
# 665                       NaN       3.0
# 666                       NaN    4448.0
# 667                Tony Zhang    1133.0
# 668              Ryan Niehaus   25273.0
# 669            Helena van Tol     345.0
# 670      Michael Wolf Hoffman   18625.0
# 671                       NaN       0.0
#
# [672 rows x 8 columns]
